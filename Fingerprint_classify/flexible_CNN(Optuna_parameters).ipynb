# %% [markdown]
# # Flexible CNN模型 - 使用Optuna得到的最优参数
# 参数：1889070
# #### Best trial:
# Best trial:                     \
#   Value: 80.9091                \
#   Params:
#     n_layers: 6
#     n_filters_layer0: 32
#     kernel_size_layer0: 3
#     n_filters_layer1: 32
#     kernel_size_layer1: 3
#     n_filters_layer2: 32
#     kernel_size_layer2: 3
#     n_filters_layer3: 128
#     kernel_size_layer3: 3
#     n_filters_layer4: 512
#     kernel_size_layer4: 5
#     n_filters_layer5: 32
#     kernel_size_layer5: 5
#     dropout_rate: 0.3495822457727959
#     fc_size: 1024
#     batch_size: 16

# %% [markdown]
# 1. 采用**分层采样**：“每个手指固定 6 张训练、2 张测试”
# 能确保模型在训练时见过每一个手指，在测试时也能评估每一个手指。
# 2. 训练集：测试集 = 6:2，保持了合理的训练数据量，同时保证了测试的代表性。
# 3. **使用LR=0.001并进行学习率衰退**

# %% [markdown]
# **Result: %的测试准确率**

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
import matplotlib.pyplot as plt
from PIL import Image
from tqdm.auto import tqdm

from torch.utils.data import Subset
from collections import defaultdict
import random

# %%
BATCH_SIZE = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1. 读取指纹数据

# %%
class FVC2002Dataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        # 过滤出所有的 .tif 文件
        self.image_files = [f for f in os.listdir(root_dir) if f.endswith('.tif')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.root_dir, img_name)
        
        # 加载图像并转为灰度图（指纹图通常是单通道）
        image = Image.open(img_path).convert('L')
        
        # 解析标签：例如 "10_3.tif" -> 标签为 10
        # 注意：类别索引通常从 0 开始，所以我们将 ID 减 1
        label = int(img_name.split('_')[0]) - 1
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# %% [markdown]
# #### 计算数据集的std和mean

# %%
# 临时加载数据集（仅 ToTensor）
dataset = FVC2002Dataset(root_dir='../FVC2002/Db1',
                        transform=transforms.Compose([
                        transforms.Grayscale(),
                        transforms.ToTensor()
                               ]))
loader = DataLoader(dataset, batch_size=100, shuffle=False)

# def get_mean_and_std(loader):
#     mean = 0.
#     std = 0.
#     total_images_count = 0
#     for images, _ in loader:
#         image_count_in_batch = images.size(0)
#         images = images.view(image_count_in_batch, images.size(1), -1)
#         mean += images.mean(2).sum(0)
#         std += images.std(2).sum(0)
#         total_images_count += image_count_in_batch
#     mean /= total_images_count
#     std /= total_images_count
#     return mean, std

# mean, std = get_mean_and_std(loader)
# print(f"Mean: {mean}, Std: {std}")

def calculate_mean_std(dataset):
    """
    Calculates the mean and standard deviation of a PyTorch dataset.

    Args:
        dataset (torch.utils.data.Dataset): The dataset for which to
                                            calculate the stats. It should
                                            return image tensors.

    Returns:
        (torch.Tensor, torch.Tensor): A tuple containing the mean and
                                      standard deviation tensors, each of
                                      shape (C,).
    """
    # Create a DataLoader to iterate through the dataset in batches for efficiency.
    # shuffle=False because the order of images doesn't matter for this calculation.
    loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=0)

    # Initialize tensors to store the sum of pixel values for each (RGB) channel.
    channel_sum = torch.zeros(1)
    # Initialize tensors to store the sum of squared pixel values for each channel.
    channel_sum_sq = torch.zeros(1)
    # Initialize a counter for the total number of pixels.
    num_pixels = 0

    # Wrap the loader with tqdm to create a progress bar for monitoring.
    for images, _ in tqdm(loader, desc="Calculating Dataset Stats"):
        # Add the total number of pixels in this batch to the running total.
        num_pixels += images.size(0) * images.size(2) * images.size(3)
        
        # Sum the pixel values across the batch, height, and width dimensions,
        # leaving only the channel dimension. Add this to the running total.
        channel_sum += images.sum(dim=[0, 2, 3])
        
        # Square each pixel value, then sum them up similarly to the step above.
        channel_sum_sq += (images ** 2).sum(dim=[0, 2, 3])

    # Calculate the mean for each channel.
    mean = channel_sum / num_pixels
    # Calculate the standard deviation using the formula: sqrt(E[X^2] - E[X]^2)
    std = (channel_sum_sq / num_pixels - mean ** 2) ** 0.5

    # Return the calculated mean and standard deviation.
    return mean, std

mean, std = calculate_mean_std(dataset)
print(f"Mean: {mean}, Std: {std}")
# Out:
# Calculating Dataset Stats:   0%|          | 0/14 [00:00<?, ?it/s]
# Mean: tensor([0.8499]), Std: tensor([0.2547])

# %%
# 指纹图片查看
def visualize_fvc_samples(dataset, num_people=2, samples_per_person=5):
    # 1. 建立 ID 到 索引列表的映射
    # label 是 img_name.split('_')[0] - 1
    id_to_indices = {}
    for idx, img_name in enumerate(dataset.image_files):
        label = int(img_name.split('_')[0]) - 1
        if label not in id_to_indices:
            id_to_indices[label] = []
        id_to_indices[label].append(idx)

    # 2. 随机抽取指定数量的人
    selected_ids = random.sample(list(id_to_indices.keys()), num_people)

    # 3. 开始绘图
    fig, axes = plt.subplots(num_people, samples_per_person, figsize=(15, 6), dpi=300)
    fig.suptitle('FVC2002 Fingerprint Samples Visualization', fontsize=16)

    for i, person_id in enumerate(selected_ids):
        # 随机抽取该人的 5 个指纹索引
        indices = random.sample(id_to_indices[person_id], samples_per_person)
        
        for j, idx in enumerate(indices):
            image, label = dataset[idx]
            
            # 如果 image 是 Tensor (经过了 transform)，需要转回 numpy
            if torch.is_tensor(image):
                image = image.squeeze().numpy() # 移除通道维度 [1, H, W] -> [H, W]
            
            ax = axes[i, j] if num_people > 1 else axes[j]
            ax.imshow(image, cmap='gray')
            ax.set_title(f"ID: {person_id + 1}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# 使用方法：
visualize_fvc_samples(dataset, num_people=2, samples_per_person=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 39
#      36     plt.show()
#      38 # 使用方法：
# ---> 39 visualize_fvc_samples(dataset, num_people=2, samples_per_person=5)
#
# NameError: name 'dataset' is not defined

# %%
class ApplyTransform(Dataset):
    """
    一个简单的装饰器类，用于给 Subset 应用特定的 transform
    """
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
        
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
        
    def __len__(self):
        return len(self.subset)

# 1. 定义两个不同的 Pipeline
# 基础操作（训练和测试共有）
base_ops = [
    transforms.CenterCrop(320),  # 中心裁剪到320x320
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.85], std=[0.2547])     # 标准差变化
]

# 训练集特有：加入随机旋转
train_transforms = transforms.Compose([
    transforms.RandomRotation(25, fill=(255,)),  # 随机旋转 ±25 度，空白处填充白色
    *base_ops
])

# 测试集：仅基础操作
test_transforms = transforms.Compose(base_ops)

# 2. 原始数据集加载时不带 transform (或者只带 Resize)
full_dataset = FVC2002Dataset(root_dir='../FVC2002/Db1', transform=None)

# --- 2. 建立标签到索引的映射 (字典结构) ---
# 这一步是为了找出每个手指对应的 8 张图分别在列表的哪个位置
label_to_indices = defaultdict(list)
for idx, img_name in enumerate(full_dataset.image_files):
    # 使用与你 Dataset 类中一致的解析逻辑
    label = int(img_name.split('_')[0]) - 1
    label_to_indices[label].append(idx)

train_indices = []
test_indices = []

# --- 3. 核心：对每一个类别固定分配 6/2 ---
# 确保每个类（手指）都参与了划分
for label, indices in label_to_indices.items():
    # 随机打乱当前手指的 8 张图索引
    random.shuffle(indices)
    
    # 取前 6 张作为训练，后 2 张作为测试
    train_indices.extend(indices[:6])
    test_indices.extend(indices[6:])

# --- 4. 创建 Subset 并应用不同的 Transform ---
# 先利用索引创建子集
train_subset = Subset(full_dataset, train_indices)
test_subset = Subset(full_dataset, test_indices)
# 5. 分别包装，应用不同的 transform
train_dataset = ApplyTransform(train_subset, transform=train_transforms)
test_dataset = ApplyTransform(test_subset, transform=test_transforms)

# %%
len(train_dataset), len(test_dataset)
# Out:
# (660, 220)

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ## 2. 构建模型

# %%
# 设计一个灵活的 CNN 模型，允许用户指定卷积层数、每层的滤波器数量、卷积核大小、Dropout率、全连接层大小等超参数
# 在训练之前需要进行一次dummy forward，来根据卷积层的输出特征图大小自动计算全连接层的输入维度

class FlexibleCNN(nn.Module):
    def __init__(self, input_shape, n_layers, n_filters, kernel_sizes, dropout_rate, fc_size, num_classes):
        super(FlexibleCNN, self).__init__()
        blocks = []
        in_channels = input_shape[0] # grey fingerprint

        for i in range(n_layers):
            out_channels = n_filters[i]
            kernel_size = kernel_sizes[i]
            padding = kernel_size // 2 # 保持尺寸不变
            
            block = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)
            )
            blocks.append(block)
            in_channels = out_channels

        self.features = nn.Sequential(*blocks)

        # --- 加入全局平均池化层 ---
        # 无论特征图多大，都压缩成 (batch, channels, 1, 1)
        self.gap = nn.AdaptiveAvgPool2d((1, 1))

        # 2. 执行 Dummy Forward 以计算全连接层的输入尺寸
        self.flattened_size = self._get_conv_output_shape(input_shape)

        # 3. 构建分类器 (在 __init__ 中完成，确保参数被注册)
        self.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.flattened_size, fc_size),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(fc_size, num_classes)
        )


    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)  # 应用全局平均池化
        x = torch.flatten(x, 1) # 展平为 (batch_size, flattened_size)
        x = self.classifier(x)
        return x
    
    def _get_conv_output_shape(self, shape):
        with torch.no_grad():
            batch_size = 1
            dummy_input = torch.ones(batch_size, *shape)
            output_tensor = self.features(dummy_input)
            output_tensor = self.gap(output_tensor)  # 应用全局平均池化
            output_size = output_tensor.view(batch_size, -1).size(1)
            return output_size

def get_flexible_cnn(num_classes=110):
    input_shape = (1, 224, 224) # 单通道输入，224x224
    n_layers = 6
    n_filters = [32, 32, 32, 128, 512, 32]
    kernel_sizes = [3, 3, 3, 3, 5, 5]
    dropout_rate = 0.34958
    fc_size = 1024
    
    model = FlexibleCNN(input_shape, n_layers, n_filters, kernel_sizes, dropout_rate, fc_size, num_classes)
    return model

# %% [markdown]
# ## 3. 模型训练

# %%
# 1. 训练一个 Epoch 的函数
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
    train_loss = running_loss / len(loader)
    train_acc = 100. * correct / total
    return train_loss, train_acc

# %%
# 2. 验证/测试函数 (基于你提供的 evaluate 修改)
def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            
    val_loss = running_loss / len(loader)
    val_acc = 100. * correct / total
    return val_loss, val_acc

# %%
# 3. 总训练控制函数
def train(model, train_loader, test_loader, criterion, optimizer, device, scheduler=None, epochs=20):
    # 用于记录历史数据以便绘图
    history = {
        'train_loss': [], 'train_acc': [],
        'test_loss': [], 'test_acc': []
    }
    
    print(f"开始训练，设备: {device}")
    for epoch in range(epochs):
        # 训练阶段
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        # 验证阶段
        test_loss, test_acc = validate(model, test_loader, criterion, device)
        
        # 每个 epoch 结束更新学习率
        if scheduler is not None:
            if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_acc)  # 以验证准确率为指标调整学习率
            else:
                scheduler.step()  # 其他类型的调度器直接调用 step()
            current_lr = optimizer.param_groups[0]['lr']

        # 记录历史
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        
        print(f"[Epoch {epoch+1}/{epochs}](LR: {current_lr:.6f}) -> "
              f"Train Acc: {train_acc:.2f}%, Test Acc: {test_acc:.2f}% | "
              f"Train Loss: {train_loss:.4f}")

    # 训练结束后进行可视化
    plot_history(history)
    return history

# 4. 可视化函数
def plot_history(history):
    epochs = range(1, len(history['train_acc']) + 1)
    
    plt.figure(figsize=(12, 5))
    
    # 绘制准确率曲线
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Acc')
    plt.plot(epochs, history['test_acc'], 'r-', label='Test Acc')
    plt.title('Training and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    
    # 绘制损失曲线
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['test_loss'], 'r-', label='Test Loss')
    plt.title('Training and Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.1 ResNet18

# %% [markdown]
# ### 3.1.1 预训练模型

# %% [markdown]
# ##### 余弦退火

# %%
flexible_cnn = get_flexible_cnn(num_classes=110).to(device)
optimizer = optim.Adam(flexible_cnn.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-5)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in flexible_cnn.parameters())
print(f"总参数量: {total_params:,}")
history1 = train(flexible_cnn, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=200)
# Out:
# 总参数量: 1,889,070
# 开始训练，设备: cuda
# [Epoch 1/200](LR: 0.001000) -> Train Acc: 0.61%, Test Acc: 1.36% | Train Loss: 4.8436
# [Epoch 2/200](LR: 0.001000) -> Train Acc: 1.97%, Test Acc: 1.36% | Train Loss: 4.6592
# [Epoch 3/200](LR: 0.000999) -> Train Acc: 2.42%, Test Acc: 2.73% | Train Loss: 4.5278
# [Epoch 4/200](LR: 0.000999) -> Train Acc: 3.18%, Test Acc: 4.09% | Train Loss: 4.3256
# [Epoch 5/200](LR: 0.000998) -> Train Acc: 6.82%, Test Acc: 4.09% | Train Loss: 4.0739
# [Epoch 6/200](LR: 0.000998) -> Train Acc: 5.30%, Test Acc: 4.55% | Train Loss: 3.9458
# [Epoch 7/200](LR: 0.000997) -> Train Acc: 6.52%, Test Acc: 5.91% | Train Loss: 3.7753
# [Epoch 8/200](LR: 0.000996) -> Train Acc: 7.88%, Test Acc: 14.55% | Train Loss: 3.6809
# [Epoch 9/200](LR: 0.000995) -> Train Acc: 11.21%, Test Acc: 10.45% | Train Loss: 3.4472
# [Epoch 10/200](LR: 0.000994) -> Train Acc: 11.67%, Test Acc: 10.91% | Train Loss: 3.4192
# [Epoch 11/200](LR: 0.000993) -> Train Acc: 11.06%, Test Acc: 11.82% | Train Loss: 3.2570
# [Epoch 12/200](LR: 0.000991) -> Train Acc: 15.76%, Test Acc: 14.09% | Train Loss: 3.1484
# [Epoch 13/200](LR: 0.000990) -> Train Acc: 16.97%, Test Acc: 18.18% | Train Loss: 3.0334
# [Epoch 14/200](LR: 0.000988) -> Train Acc: 18.79%, Test Acc: 14.09% | Train Loss: 2.8409
# [Epoch 15/200](LR: 0.000986) -> Train Acc: 21.36%, Test Acc: 20.00% | Train Loss: 2.7813
# [Epoch 16/200](LR: 0.000984) -> Train Acc: 24.09%, Test Acc: 24.55% | Train Loss: 2.6218
# [Epoch 17/200](LR: 0.000982) -> Train Acc: 27.42%, Test Acc: 15.91% | Train Loss: 2.5266
# [Epoch 18/200](LR: 0.000980) -> Train Acc: 28.18%, Test Acc: 28.64% | Train Loss: 2.4213
# [Epoch 19/200](LR: 0.000978) -> Train Acc: 29.85%, Test Acc: 30.45% | Train Loss: 2.4086
# [Epoch 20/200](LR: 0.000976) -> Train Acc: 31.36%, Test Acc: 32.73% | Train Loss: 2.3804
# [Epoch 21/200](LR: 0.000973) -> Train Acc: 32.58%, Test Acc: 20.45% | Train Loss: 2.2284
# [Epoch 22/200](LR: 0.000971) -> Train Acc: 34.09%, Test Acc: 25.45% | Train Loss: 2.1878
# [Epoch 23/200](LR: 0.000968) -> Train Acc: 35.61%, Test Acc: 28.18% | Train Loss: 2.0914
# [Epoch 24/200](LR: 0.000965) -> Train Acc: 34.85%, Test Acc: 17.73% | Train Loss: 2.1030
# [Epoch 25/200](LR: 0.000962) -> Train Acc: 37.27%, Test Acc: 15.91% | Train Loss: 2.0281
# [Epoch 26/200](LR: 0.000959) -> Train Acc: 40.61%, Test Acc: 36.36% | Train Loss: 1.9161
# [Epoch 27/200](LR: 0.000956) -> Train Acc: 40.45%, Test Acc: 42.27% | Train Loss: 1.8596
# [Epoch 28/200](LR: 0.000953) -> Train Acc: 43.94%, Test Acc: 21.82% | Train Loss: 1.8301
# [Epoch 29/200](LR: 0.000950) -> Train Acc: 45.76%, Test Acc: 44.55% | Train Loss: 1.7744
# [Epoch 30/200](LR: 0.000946) -> Train Acc: 43.79%, Test Acc: 24.55% | Train Loss: 1.7933
# [Epoch 31/200](LR: 0.000942) -> Train Acc: 46.36%, Test Acc: 36.36% | Train Loss: 1.7416
# [Epoch 32/200](LR: 0.000939) -> Train Acc: 44.24%, Test Acc: 53.18% | Train Loss: 1.7124
# [Epoch 33/200](LR: 0.000935) -> Train Acc: 46.21%, Test Acc: 33.64% | Train Loss: 1.6677
# [Epoch 34/200](LR: 0.000931) -> Train Acc: 52.27%, Test Acc: 41.36% | Train Loss: 1.5155
# [Epoch 35/200](LR: 0.000927) -> Train Acc: 50.91%, Test Acc: 37.27% | Train Loss: 1.5798
# [Epoch 36/200](LR: 0.000923) -> Train Acc: 53.94%, Test Acc: 50.00% | Train Loss: 1.4997
# [Epoch 37/200](LR: 0.000919) -> Train Acc: 52.88%, Test Acc: 30.00% | Train Loss: 1.4503
# [Epoch 38/200](LR: 0.000914) -> Train Acc: 58.03%, Test Acc: 39.09% | Train Loss: 1.3578
# [Epoch 39/200](LR: 0.000910) -> Train Acc: 55.76%, Test Acc: 45.91% | Train Loss: 1.3369
# [Epoch 40/200](LR: 0.000905) -> Train Acc: 57.42%, Test Acc: 33.18% | Train Loss: 1.3188
# [Epoch 41/200](LR: 0.000901) -> Train Acc: 58.03%, Test Acc: 46.82% | Train Loss: 1.2585
# [Epoch 42/200](LR: 0.000896) -> Train Acc: 57.42%, Test Acc: 58.18% | Train Loss: 1.3328
# [Epoch 43/200](LR: 0.000891) -> Train Acc: 60.91%, Test Acc: 54.55% | Train Loss: 1.1943
# [Epoch 44/200](LR: 0.000886) -> Train Acc: 64.39%, Test Acc: 54.09% | Train Loss: 1.1173
# [Epoch 45/200](LR: 0.000881) -> Train Acc: 58.18%, Test Acc: 53.18% | Train Loss: 1.2669
# [Epoch 46/200](LR: 0.000876) -> Train Acc: 58.79%, Test Acc: 56.36% | Train Loss: 1.1633
# [Epoch 47/200](LR: 0.000871) -> Train Acc: 64.55%, Test Acc: 49.09% | Train Loss: 1.1195
# [Epoch 48/200](LR: 0.000866) -> Train Acc: 61.97%, Test Acc: 59.09% | Train Loss: 1.1090
# [Epoch 49/200](LR: 0.000860) -> Train Acc: 61.82%, Test Acc: 60.00% | Train Loss: 1.1791
# [Epoch 50/200](LR: 0.000855) -> Train Acc: 61.21%, Test Acc: 36.82% | Train Loss: 1.1662
# [Epoch 51/200](LR: 0.000849) -> Train Acc: 64.55%, Test Acc: 56.82% | Train Loss: 1.0580
# [Epoch 52/200](LR: 0.000844) -> Train Acc: 67.58%, Test Acc: 55.45% | Train Loss: 1.0236
# [Epoch 53/200](LR: 0.000838) -> Train Acc: 67.12%, Test Acc: 59.55% | Train Loss: 0.9641
# [Epoch 54/200](LR: 0.000832) -> Train Acc: 70.00%, Test Acc: 59.09% | Train Loss: 0.9756
# [Epoch 55/200](LR: 0.000826) -> Train Acc: 70.76%, Test Acc: 51.36% | Train Loss: 0.8742
# [Epoch 56/200](LR: 0.000821) -> Train Acc: 70.15%, Test Acc: 65.00% | Train Loss: 0.8552
# [Epoch 57/200](LR: 0.000814) -> Train Acc: 71.36%, Test Acc: 65.45% | Train Loss: 0.8780
# [Epoch 58/200](LR: 0.000808) -> Train Acc: 73.33%, Test Acc: 55.00% | Train Loss: 0.8695
# [Epoch 59/200](LR: 0.000802) -> Train Acc: 71.82%, Test Acc: 66.82% | Train Loss: 0.8886
# [Epoch 60/200](LR: 0.000796) -> Train Acc: 71.21%, Test Acc: 58.64% | Train Loss: 0.7897
# [Epoch 61/200](LR: 0.000790) -> Train Acc: 76.36%, Test Acc: 68.18% | Train Loss: 0.7398
# [Epoch 62/200](LR: 0.000783) -> Train Acc: 71.82%, Test Acc: 39.55% | Train Loss: 0.8619
# [Epoch 63/200](LR: 0.000777) -> Train Acc: 72.58%, Test Acc: 58.18% | Train Loss: 0.8156
# [Epoch 64/200](LR: 0.000770) -> Train Acc: 75.15%, Test Acc: 44.55% | Train Loss: 0.7425
# [Epoch 65/200](LR: 0.000764) -> Train Acc: 73.18%, Test Acc: 57.27% | Train Loss: 0.7931
# [Epoch 66/200](LR: 0.000757) -> Train Acc: 77.58%, Test Acc: 52.27% | Train Loss: 0.6807
# [Epoch 67/200](LR: 0.000750) -> Train Acc: 74.85%, Test Acc: 73.18% | Train Loss: 0.7248
# [Epoch 68/200](LR: 0.000743) -> Train Acc: 77.58%, Test Acc: 64.09% | Train Loss: 0.6657
# [Epoch 69/200](LR: 0.000737) -> Train Acc: 77.58%, Test Acc: 68.64% | Train Loss: 0.6957
# [Epoch 70/200](LR: 0.000730) -> Train Acc: 77.58%, Test Acc: 68.18% | Train Loss: 0.6786
# [Epoch 71/200](LR: 0.000723) -> Train Acc: 77.12%, Test Acc: 65.91% | Train Loss: 0.6848
# [Epoch 72/200](LR: 0.000716) -> Train Acc: 78.79%, Test Acc: 59.55% | Train Loss: 0.6786
# [Epoch 73/200](LR: 0.000709) -> Train Acc: 78.33%, Test Acc: 71.82% | Train Loss: 0.6427
# [Epoch 74/200](LR: 0.000702) -> Train Acc: 81.52%, Test Acc: 65.00% | Train Loss: 0.5735
# [Epoch 75/200](LR: 0.000694) -> Train Acc: 79.55%, Test Acc: 54.09% | Train Loss: 0.6327
# [Epoch 76/200](LR: 0.000687) -> Train Acc: 81.06%, Test Acc: 69.55% | Train Loss: 0.5806
# [Epoch 77/200](LR: 0.000680) -> Train Acc: 80.30%, Test Acc: 69.55% | Train Loss: 0.5768
# [Epoch 78/200](LR: 0.000673) -> Train Acc: 84.55%, Test Acc: 70.45% | Train Loss: 0.4913
# [Epoch 79/200](LR: 0.000665) -> Train Acc: 83.79%, Test Acc: 70.00% | Train Loss: 0.4837
# [Epoch 80/200](LR: 0.000658) -> Train Acc: 84.09%, Test Acc: 64.09% | Train Loss: 0.5060
# [Epoch 81/200](LR: 0.000651) -> Train Acc: 83.79%, Test Acc: 69.09% | Train Loss: 0.4690
# [Epoch 82/200](LR: 0.000643) -> Train Acc: 84.70%, Test Acc: 66.36% | Train Loss: 0.4666
# [Epoch 83/200](LR: 0.000636) -> Train Acc: 82.12%, Test Acc: 70.45% | Train Loss: 0.5291
# [Epoch 84/200](LR: 0.000628) -> Train Acc: 81.67%, Test Acc: 72.73% | Train Loss: 0.5121
# [Epoch 85/200](LR: 0.000621) -> Train Acc: 83.03%, Test Acc: 73.64% | Train Loss: 0.4783
# [Epoch 86/200](LR: 0.000613) -> Train Acc: 84.09%, Test Acc: 69.09% | Train Loss: 0.5031
# [Epoch 87/200](LR: 0.000605) -> Train Acc: 87.27%, Test Acc: 75.91% | Train Loss: 0.4151
# [Epoch 88/200](LR: 0.000598) -> Train Acc: 86.21%, Test Acc: 76.36% | Train Loss: 0.4503
# [Epoch 89/200](LR: 0.000590) -> Train Acc: 84.85%, Test Acc: 71.36% | Train Loss: 0.4469
# [Epoch 90/200](LR: 0.000582) -> Train Acc: 84.85%, Test Acc: 66.82% | Train Loss: 0.4847
# [Epoch 91/200](LR: 0.000575) -> Train Acc: 86.52%, Test Acc: 71.82% | Train Loss: 0.4349
# [Epoch 92/200](LR: 0.000567) -> Train Acc: 84.70%, Test Acc: 71.36% | Train Loss: 0.4540
# [Epoch 93/200](LR: 0.000559) -> Train Acc: 84.55%, Test Acc: 71.36% | Train Loss: 0.4498
# [Epoch 94/200](LR: 0.000552) -> Train Acc: 87.27%, Test Acc: 69.55% | Train Loss: 0.4130
# [Epoch 95/200](LR: 0.000544) -> Train Acc: 87.27%, Test Acc: 72.73% | Train Loss: 0.3804
# [Epoch 96/200](LR: 0.000536) -> Train Acc: 89.55%, Test Acc: 75.91% | Train Loss: 0.3129
# [Epoch 97/200](LR: 0.000528) -> Train Acc: 84.55%, Test Acc: 78.64% | Train Loss: 0.4585
# [Epoch 98/200](LR: 0.000521) -> Train Acc: 87.73%, Test Acc: 77.27% | Train Loss: 0.3727
# [Epoch 99/200](LR: 0.000513) -> Train Acc: 90.91%, Test Acc: 75.91% | Train Loss: 0.2949
# [Epoch 100/200](LR: 0.000505) -> Train Acc: 90.30%, Test Acc: 80.00% | Train Loss: 0.3237
# [Epoch 101/200](LR: 0.000497) -> Train Acc: 88.03%, Test Acc: 78.18% | Train Loss: 0.3647
# [Epoch 102/200](LR: 0.000489) -> Train Acc: 88.48%, Test Acc: 79.55% | Train Loss: 0.3497
# [Epoch 103/200](LR: 0.000482) -> Train Acc: 90.61%, Test Acc: 75.45% | Train Loss: 0.2893
# [Epoch 104/200](LR: 0.000474) -> Train Acc: 90.61%, Test Acc: 77.27% | Train Loss: 0.3181
# [Epoch 105/200](LR: 0.000466) -> Train Acc: 86.52%, Test Acc: 77.73% | Train Loss: 0.3859
# [Epoch 106/200](LR: 0.000458) -> Train Acc: 88.33%, Test Acc: 71.82% | Train Loss: 0.3346
# [Epoch 107/200](LR: 0.000451) -> Train Acc: 92.42%, Test Acc: 79.55% | Train Loss: 0.2592
# [Epoch 108/200](LR: 0.000443) -> Train Acc: 93.18%, Test Acc: 82.73% | Train Loss: 0.2594
# [Epoch 109/200](LR: 0.000435) -> Train Acc: 91.21%, Test Acc: 79.09% | Train Loss: 0.2962
# [Epoch 110/200](LR: 0.000428) -> Train Acc: 92.27%, Test Acc: 81.82% | Train Loss: 0.2497
# [Epoch 111/200](LR: 0.000420) -> Train Acc: 89.55%, Test Acc: 76.36% | Train Loss: 0.2949
# [Epoch 112/200](LR: 0.000412) -> Train Acc: 90.61%, Test Acc: 79.09% | Train Loss: 0.2720
# [Epoch 113/200](LR: 0.000405) -> Train Acc: 89.85%, Test Acc: 82.73% | Train Loss: 0.3111
# [Epoch 114/200](LR: 0.000397) -> Train Acc: 91.21%, Test Acc: 77.27% | Train Loss: 0.2769
# [Epoch 115/200](LR: 0.000389) -> Train Acc: 90.76%, Test Acc: 74.55% | Train Loss: 0.2932
# [Epoch 116/200](LR: 0.000382) -> Train Acc: 92.42%, Test Acc: 79.09% | Train Loss: 0.2643
# [Epoch 117/200](LR: 0.000374) -> Train Acc: 93.48%, Test Acc: 80.00% | Train Loss: 0.2394
# [Epoch 118/200](LR: 0.000367) -> Train Acc: 91.21%, Test Acc: 80.91% | Train Loss: 0.2656
# [Epoch 119/200](LR: 0.000359) -> Train Acc: 92.12%, Test Acc: 77.27% | Train Loss: 0.2453
# [Epoch 120/200](LR: 0.000352) -> Train Acc: 93.03%, Test Acc: 81.82% | Train Loss: 0.2521
# [Epoch 121/200](LR: 0.000345) -> Train Acc: 92.27%, Test Acc: 79.09% | Train Loss: 0.2715
# [Epoch 122/200](LR: 0.000337) -> Train Acc: 94.70%, Test Acc: 80.45% | Train Loss: 0.1923
# [Epoch 123/200](LR: 0.000330) -> Train Acc: 92.27%, Test Acc: 82.73% | Train Loss: 0.2569
# [Epoch 124/200](LR: 0.000323) -> Train Acc: 94.55%, Test Acc: 82.27% | Train Loss: 0.2130
# [Epoch 125/200](LR: 0.000316) -> Train Acc: 93.03%, Test Acc: 84.09% | Train Loss: 0.2092
# [Epoch 126/200](LR: 0.000308) -> Train Acc: 95.30%, Test Acc: 79.55% | Train Loss: 0.1779
# [Epoch 127/200](LR: 0.000301) -> Train Acc: 93.18%, Test Acc: 82.73% | Train Loss: 0.2445
# [Epoch 128/200](LR: 0.000294) -> Train Acc: 93.03%, Test Acc: 81.36% | Train Loss: 0.2144
# [Epoch 129/200](LR: 0.000287) -> Train Acc: 94.39%, Test Acc: 81.82% | Train Loss: 0.1868
# [Epoch 130/200](LR: 0.000280) -> Train Acc: 94.39%, Test Acc: 80.45% | Train Loss: 0.1955
# [Epoch 131/200](LR: 0.000273) -> Train Acc: 95.15%, Test Acc: 81.82% | Train Loss: 0.1708
# [Epoch 132/200](LR: 0.000267) -> Train Acc: 93.48%, Test Acc: 80.45% | Train Loss: 0.1941
# [Epoch 133/200](LR: 0.000260) -> Train Acc: 94.55%, Test Acc: 80.00% | Train Loss: 0.1739
# [Epoch 134/200](LR: 0.000253) -> Train Acc: 94.09%, Test Acc: 83.18% | Train Loss: 0.1995
# [Epoch 135/200](LR: 0.000246) -> Train Acc: 93.18%, Test Acc: 82.73% | Train Loss: 0.2125
# [Epoch 136/200](LR: 0.000240) -> Train Acc: 92.42%, Test Acc: 80.91% | Train Loss: 0.2256
# [Epoch 137/200](LR: 0.000233) -> Train Acc: 95.45%, Test Acc: 82.27% | Train Loss: 0.1611
# [Epoch 138/200](LR: 0.000227) -> Train Acc: 94.70%, Test Acc: 84.55% | Train Loss: 0.1908
# [Epoch 139/200](LR: 0.000220) -> Train Acc: 93.94%, Test Acc: 84.55% | Train Loss: 0.1800
# [Epoch 140/200](LR: 0.000214) -> Train Acc: 93.79%, Test Acc: 83.64% | Train Loss: 0.1936
# [Epoch 141/200](LR: 0.000208) -> Train Acc: 94.70%, Test Acc: 83.18% | Train Loss: 0.1603
# [Epoch 142/200](LR: 0.000202) -> Train Acc: 95.91%, Test Acc: 84.09% | Train Loss: 0.1541
# [Epoch 143/200](LR: 0.000196) -> Train Acc: 93.79%, Test Acc: 84.55% | Train Loss: 0.1841
# [Epoch 144/200](LR: 0.000189) -> Train Acc: 96.36%, Test Acc: 82.27% | Train Loss: 0.1705
# [Epoch 145/200](LR: 0.000184) -> Train Acc: 96.52%, Test Acc: 82.73% | Train Loss: 0.1331
# [Epoch 146/200](LR: 0.000178) -> Train Acc: 93.79%, Test Acc: 82.73% | Train Loss: 0.1933
# [Epoch 147/200](LR: 0.000172) -> Train Acc: 94.70%, Test Acc: 82.73% | Train Loss: 0.1679
# [Epoch 148/200](LR: 0.000166) -> Train Acc: 93.94%, Test Acc: 81.36% | Train Loss: 0.1701
# [Epoch 149/200](LR: 0.000161) -> Train Acc: 96.06%, Test Acc: 85.45% | Train Loss: 0.1365
# [Epoch 150/200](LR: 0.000155) -> Train Acc: 95.00%, Test Acc: 85.00% | Train Loss: 0.1695
# [Epoch 151/200](LR: 0.000150) -> Train Acc: 94.55%, Test Acc: 85.00% | Train Loss: 0.1822
# [Epoch 152/200](LR: 0.000144) -> Train Acc: 95.00%, Test Acc: 85.00% | Train Loss: 0.1649
# [Epoch 153/200](LR: 0.000139) -> Train Acc: 96.21%, Test Acc: 85.00% | Train Loss: 0.1339
# [Epoch 154/200](LR: 0.000134) -> Train Acc: 95.30%, Test Acc: 85.45% | Train Loss: 0.1622
# [Epoch 155/200](LR: 0.000129) -> Train Acc: 97.58%, Test Acc: 85.00% | Train Loss: 0.1089
# [Epoch 156/200](LR: 0.000124) -> Train Acc: 96.67%, Test Acc: 84.55% | Train Loss: 0.1304
# [Epoch 157/200](LR: 0.000119) -> Train Acc: 95.45%, Test Acc: 84.55% | Train Loss: 0.1699
# [Epoch 158/200](LR: 0.000114) -> Train Acc: 95.91%, Test Acc: 84.09% | Train Loss: 0.1439
# [Epoch 159/200](LR: 0.000109) -> Train Acc: 97.27%, Test Acc: 85.45% | Train Loss: 0.1062
# [Epoch 160/200](LR: 0.000105) -> Train Acc: 96.82%, Test Acc: 85.00% | Train Loss: 0.1296
# [Epoch 161/200](LR: 0.000100) -> Train Acc: 94.70%, Test Acc: 85.00% | Train Loss: 0.1525
# [Epoch 162/200](LR: 0.000096) -> Train Acc: 95.45%, Test Acc: 85.00% | Train Loss: 0.1476
# [Epoch 163/200](LR: 0.000091) -> Train Acc: 96.52%, Test Acc: 85.45% | Train Loss: 0.1306
# [Epoch 164/200](LR: 0.000087) -> Train Acc: 97.88%, Test Acc: 85.45% | Train Loss: 0.0952
# [Epoch 165/200](LR: 0.000083) -> Train Acc: 97.42%, Test Acc: 85.45% | Train Loss: 0.1244
# [Epoch 166/200](LR: 0.000079) -> Train Acc: 97.58%, Test Acc: 85.91% | Train Loss: 0.1189
# [Epoch 167/200](LR: 0.000075) -> Train Acc: 97.12%, Test Acc: 85.45% | Train Loss: 0.1231
# [Epoch 168/200](LR: 0.000071) -> Train Acc: 96.21%, Test Acc: 85.00% | Train Loss: 0.1343
# [Epoch 169/200](LR: 0.000068) -> Train Acc: 96.97%, Test Acc: 86.82% | Train Loss: 0.1289
# [Epoch 170/200](LR: 0.000064) -> Train Acc: 96.82%, Test Acc: 85.91% | Train Loss: 0.1140
# [Epoch 171/200](LR: 0.000060) -> Train Acc: 95.91%, Test Acc: 83.64% | Train Loss: 0.1375
# [Epoch 172/200](LR: 0.000057) -> Train Acc: 95.45%, Test Acc: 85.00% | Train Loss: 0.1388
# [Epoch 173/200](LR: 0.000054) -> Train Acc: 95.91%, Test Acc: 85.91% | Train Loss: 0.1415
# [Epoch 174/200](LR: 0.000051) -> Train Acc: 96.82%, Test Acc: 85.00% | Train Loss: 0.1202
# [Epoch 175/200](LR: 0.000048) -> Train Acc: 97.88%, Test Acc: 85.45% | Train Loss: 0.0984
# [Epoch 176/200](LR: 0.000045) -> Train Acc: 96.36%, Test Acc: 86.36% | Train Loss: 0.1168
# [Epoch 177/200](LR: 0.000042) -> Train Acc: 96.97%, Test Acc: 87.73% | Train Loss: 0.1304
# [Epoch 178/200](LR: 0.000039) -> Train Acc: 97.42%, Test Acc: 86.82% | Train Loss: 0.1026
# [Epoch 179/200](LR: 0.000037) -> Train Acc: 96.97%, Test Acc: 86.82% | Train Loss: 0.1116
# [Epoch 180/200](LR: 0.000034) -> Train Acc: 96.67%, Test Acc: 86.36% | Train Loss: 0.1141
# [Epoch 181/200](LR: 0.000032) -> Train Acc: 96.82%, Test Acc: 86.36% | Train Loss: 0.1203
# [Epoch 182/200](LR: 0.000030) -> Train Acc: 96.82%, Test Acc: 86.36% | Train Loss: 0.0974
# [Epoch 183/200](LR: 0.000028) -> Train Acc: 97.12%, Test Acc: 86.82% | Train Loss: 0.1204
# [Epoch 184/200](LR: 0.000026) -> Train Acc: 97.42%, Test Acc: 87.27% | Train Loss: 0.1029
# [Epoch 185/200](LR: 0.000024) -> Train Acc: 96.36%, Test Acc: 86.36% | Train Loss: 0.1102
# [Epoch 186/200](LR: 0.000022) -> Train Acc: 96.82%, Test Acc: 86.82% | Train Loss: 0.1170
# [Epoch 187/200](LR: 0.000020) -> Train Acc: 97.73%, Test Acc: 86.36% | Train Loss: 0.0980
# [Epoch 188/200](LR: 0.000019) -> Train Acc: 97.42%, Test Acc: 86.36% | Train Loss: 0.1004
# [Epoch 189/200](LR: 0.000017) -> Train Acc: 96.52%, Test Acc: 85.91% | Train Loss: 0.1273
# [Epoch 190/200](LR: 0.000016) -> Train Acc: 97.27%, Test Acc: 86.36% | Train Loss: 0.1044
# [Epoch 191/200](LR: 0.000015) -> Train Acc: 96.82%, Test Acc: 85.91% | Train Loss: 0.1126
# [Epoch 192/200](LR: 0.000014) -> Train Acc: 97.12%, Test Acc: 86.36% | Train Loss: 0.1066
# [Epoch 193/200](LR: 0.000013) -> Train Acc: 97.27%, Test Acc: 86.82% | Train Loss: 0.1069
# [Epoch 194/200](LR: 0.000012) -> Train Acc: 97.73%, Test Acc: 87.27% | Train Loss: 0.1095
# [Epoch 195/200](LR: 0.000012) -> Train Acc: 96.82%, Test Acc: 86.82% | Train Loss: 0.1074
# [Epoch 196/200](LR: 0.000011) -> Train Acc: 96.52%, Test Acc: 86.82% | Train Loss: 0.1153
# [Epoch 197/200](LR: 0.000011) -> Train Acc: 97.27%, Test Acc: 86.82% | Train Loss: 0.1095
# [Epoch 198/200](LR: 0.000010) -> Train Acc: 96.97%, Test Acc: 86.36% | Train Loss: 0.1046
# [Epoch 199/200](LR: 0.000010) -> Train Acc: 96.67%, Test Acc: 85.91% | Train Loss: 0.1233
# [Epoch 200/200](LR: 0.000010) -> Train Acc: 96.82%, Test Acc: 85.91% | Train Loss: 0.1123

# %% [markdown]
# ##### ReduceLROnPlateau

# %%
flexible_cnn = get_flexible_cnn(num_classes=110).to(device)
optimizer = optim.Adam(flexible_cnn.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, verbose=True)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in flexible_cnn.parameters())
print(f"总参数量: {total_params:,}")
history2 = train(flexible_cnn, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=200)
# Out:
# 总参数量: 1,889,070
# 开始训练，设备: cuda
# [Epoch 1/200](LR: 0.001000) -> Train Acc: 0.91%, Test Acc: 1.36% | Train Loss: 4.8005
# [Epoch 2/200](LR: 0.001000) -> Train Acc: 1.52%, Test Acc: 1.82% | Train Loss: 4.6616
# [Epoch 3/200](LR: 0.001000) -> Train Acc: 2.42%, Test Acc: 2.27% | Train Loss: 4.5016
# [Epoch 4/200](LR: 0.001000) -> Train Acc: 3.48%, Test Acc: 6.36% | Train Loss: 4.3075
# [Epoch 5/200](LR: 0.001000) -> Train Acc: 4.09%, Test Acc: 2.27% | Train Loss: 4.1250
# [Epoch 6/200](LR: 0.001000) -> Train Acc: 4.85%, Test Acc: 8.64% | Train Loss: 3.9312
# [Epoch 7/200](LR: 0.001000) -> Train Acc: 8.33%, Test Acc: 11.82% | Train Loss: 3.7444
# [Epoch 8/200](LR: 0.001000) -> Train Acc: 8.33%, Test Acc: 6.36% | Train Loss: 3.6111
# [Epoch 9/200](LR: 0.001000) -> Train Acc: 12.73%, Test Acc: 12.27% | Train Loss: 3.4293
# [Epoch 10/200](LR: 0.001000) -> Train Acc: 16.06%, Test Acc: 10.45% | Train Loss: 3.2369
# [Epoch 11/200](LR: 0.001000) -> Train Acc: 14.70%, Test Acc: 14.09% | Train Loss: 3.0697
# [Epoch 12/200](LR: 0.001000) -> Train Acc: 17.27%, Test Acc: 19.09% | Train Loss: 2.9680
# [Epoch 13/200](LR: 0.001000) -> Train Acc: 18.79%, Test Acc: 11.82% | Train Loss: 2.8836
# [Epoch 14/200](LR: 0.001000) -> Train Acc: 24.70%, Test Acc: 24.09% | Train Loss: 2.6330
# [Epoch 15/200](LR: 0.001000) -> Train Acc: 19.39%, Test Acc: 23.64% | Train Loss: 2.7391
# [Epoch 16/200](LR: 0.001000) -> Train Acc: 25.30%, Test Acc: 31.82% | Train Loss: 2.6400
# [Epoch 17/200](LR: 0.001000) -> Train Acc: 26.97%, Test Acc: 22.27% | Train Loss: 2.4790
# [Epoch 18/200](LR: 0.001000) -> Train Acc: 31.97%, Test Acc: 34.55% | Train Loss: 2.3167
# [Epoch 19/200](LR: 0.001000) -> Train Acc: 30.00%, Test Acc: 30.00% | Train Loss: 2.3114
# [Epoch 20/200](LR: 0.001000) -> Train Acc: 35.76%, Test Acc: 17.27% | Train Loss: 2.1340
# [Epoch 21/200](LR: 0.001000) -> Train Acc: 37.58%, Test Acc: 28.64% | Train Loss: 2.1493
# [Epoch 22/200](LR: 0.001000) -> Train Acc: 34.39%, Test Acc: 30.00% | Train Loss: 2.1646
# [Epoch 23/200](LR: 0.001000) -> Train Acc: 36.21%, Test Acc: 13.64% | Train Loss: 2.1327
# Epoch 00024: reducing learning rate of group 0 to 5.0000e-04.
# [Epoch 24/200](LR: 0.000500) -> Train Acc: 36.21%, Test Acc: 29.09% | Train Loss: 2.0827
# [Epoch 25/200](LR: 0.000500) -> Train Acc: 43.79%, Test Acc: 47.73% | Train Loss: 1.8447
# [Epoch 26/200](LR: 0.000500) -> Train Acc: 45.61%, Test Acc: 43.64% | Train Loss: 1.7914
# [Epoch 27/200](LR: 0.000500) -> Train Acc: 49.85%, Test Acc: 30.91% | Train Loss: 1.7186
# [Epoch 28/200](LR: 0.000500) -> Train Acc: 51.21%, Test Acc: 53.18% | Train Loss: 1.6356
# [Epoch 29/200](LR: 0.000500) -> Train Acc: 48.33%, Test Acc: 46.36% | Train Loss: 1.5836
# [Epoch 30/200](LR: 0.000500) -> Train Acc: 49.24%, Test Acc: 56.82% | Train Loss: 1.6187
# [Epoch 31/200](LR: 0.000500) -> Train Acc: 50.91%, Test Acc: 47.27% | Train Loss: 1.5939
# [Epoch 32/200](LR: 0.000500) -> Train Acc: 51.06%, Test Acc: 43.18% | Train Loss: 1.5575
# [Epoch 33/200](LR: 0.000500) -> Train Acc: 54.09%, Test Acc: 46.82% | Train Loss: 1.4624
# [Epoch 34/200](LR: 0.000500) -> Train Acc: 52.27%, Test Acc: 59.09% | Train Loss: 1.4989
# [Epoch 35/200](LR: 0.000500) -> Train Acc: 54.09%, Test Acc: 47.27% | Train Loss: 1.4755
# [Epoch 36/200](LR: 0.000500) -> Train Acc: 54.85%, Test Acc: 60.45% | Train Loss: 1.4076
# [Epoch 37/200](LR: 0.000500) -> Train Acc: 54.24%, Test Acc: 31.36% | Train Loss: 1.4157
# [Epoch 38/200](LR: 0.000500) -> Train Acc: 58.03%, Test Acc: 57.73% | Train Loss: 1.3515
# [Epoch 39/200](LR: 0.000500) -> Train Acc: 62.73%, Test Acc: 55.91% | Train Loss: 1.2233
# [Epoch 40/200](LR: 0.000500) -> Train Acc: 57.88%, Test Acc: 62.27% | Train Loss: 1.3063
# [Epoch 41/200](LR: 0.000500) -> Train Acc: 58.03%, Test Acc: 56.36% | Train Loss: 1.2980
# [Epoch 42/200](LR: 0.000500) -> Train Acc: 61.06%, Test Acc: 45.45% | Train Loss: 1.2258
# [Epoch 43/200](LR: 0.000500) -> Train Acc: 60.76%, Test Acc: 46.36% | Train Loss: 1.2676
# [Epoch 44/200](LR: 0.000500) -> Train Acc: 58.64%, Test Acc: 55.45% | Train Loss: 1.2490
# [Epoch 45/200](LR: 0.000500) -> Train Acc: 63.18%, Test Acc: 57.27% | Train Loss: 1.1961
# Epoch 00046: reducing learning rate of group 0 to 2.5000e-04.
# [Epoch 46/200](LR: 0.000250) -> Train Acc: 61.21%, Test Acc: 58.64% | Train Loss: 1.2041
# [Epoch 47/200](LR: 0.000250) -> Train Acc: 67.73%, Test Acc: 69.55% | Train Loss: 1.0314
# [Epoch 48/200](LR: 0.000250) -> Train Acc: 70.30%, Test Acc: 67.73% | Train Loss: 0.9731
# [Epoch 49/200](LR: 0.000250) -> Train Acc: 70.76%, Test Acc: 63.64% | Train Loss: 0.9158
# [Epoch 50/200](LR: 0.000250) -> Train Acc: 68.03%, Test Acc: 62.27% | Train Loss: 1.0025
# [Epoch 51/200](LR: 0.000250) -> Train Acc: 69.70%, Test Acc: 66.36% | Train Loss: 0.9513
# [Epoch 52/200](LR: 0.000250) -> Train Acc: 70.45%, Test Acc: 64.55% | Train Loss: 0.9629
# Epoch 00053: reducing learning rate of group 0 to 1.2500e-04.
# [Epoch 53/200](LR: 0.000125) -> Train Acc: 68.79%, Test Acc: 68.64% | Train Loss: 0.9847
# [Epoch 54/200](LR: 0.000125) -> Train Acc: 73.33%, Test Acc: 71.36% | Train Loss: 0.8838
# [Epoch 55/200](LR: 0.000125) -> Train Acc: 75.61%, Test Acc: 70.45% | Train Loss: 0.8217
# [Epoch 56/200](LR: 0.000125) -> Train Acc: 74.55%, Test Acc: 73.64% | Train Loss: 0.8638
# [Epoch 57/200](LR: 0.000125) -> Train Acc: 72.88%, Test Acc: 73.18% | Train Loss: 0.8383
# [Epoch 58/200](LR: 0.000125) -> Train Acc: 73.64%, Test Acc: 70.91% | Train Loss: 0.8756
# [Epoch 59/200](LR: 0.000125) -> Train Acc: 74.39%, Test Acc: 73.18% | Train Loss: 0.8280
# [Epoch 60/200](LR: 0.000125) -> Train Acc: 72.73%, Test Acc: 70.00% | Train Loss: 0.8697
# [Epoch 61/200](LR: 0.000125) -> Train Acc: 77.12%, Test Acc: 75.00% | Train Loss: 0.7589
# [Epoch 62/200](LR: 0.000125) -> Train Acc: 73.94%, Test Acc: 69.55% | Train Loss: 0.8391
# [Epoch 63/200](LR: 0.000125) -> Train Acc: 74.39%, Test Acc: 72.73% | Train Loss: 0.8141
# [Epoch 64/200](LR: 0.000125) -> Train Acc: 77.27%, Test Acc: 75.45% | Train Loss: 0.7770
# [Epoch 65/200](LR: 0.000125) -> Train Acc: 77.12%, Test Acc: 75.00% | Train Loss: 0.7799
# [Epoch 66/200](LR: 0.000125) -> Train Acc: 74.70%, Test Acc: 74.55% | Train Loss: 0.8191
# [Epoch 67/200](LR: 0.000125) -> Train Acc: 76.97%, Test Acc: 72.73% | Train Loss: 0.7500
# [Epoch 68/200](LR: 0.000125) -> Train Acc: 75.30%, Test Acc: 74.55% | Train Loss: 0.7939
# [Epoch 69/200](LR: 0.000125) -> Train Acc: 76.82%, Test Acc: 71.82% | Train Loss: 0.7271
# [Epoch 70/200](LR: 0.000125) -> Train Acc: 76.36%, Test Acc: 77.27% | Train Loss: 0.7575
# [Epoch 71/200](LR: 0.000125) -> Train Acc: 78.94%, Test Acc: 73.18% | Train Loss: 0.6893
# [Epoch 72/200](LR: 0.000125) -> Train Acc: 79.70%, Test Acc: 74.09% | Train Loss: 0.7152
# [Epoch 73/200](LR: 0.000125) -> Train Acc: 76.97%, Test Acc: 74.09% | Train Loss: 0.7577
# [Epoch 74/200](LR: 0.000125) -> Train Acc: 78.03%, Test Acc: 73.18% | Train Loss: 0.7216
# [Epoch 75/200](LR: 0.000125) -> Train Acc: 78.64%, Test Acc: 73.18% | Train Loss: 0.6830
# Epoch 00076: reducing learning rate of group 0 to 6.2500e-05.
# [Epoch 76/200](LR: 0.000063) -> Train Acc: 77.42%, Test Acc: 75.91% | Train Loss: 0.7195
# [Epoch 77/200](LR: 0.000063) -> Train Acc: 75.61%, Test Acc: 75.45% | Train Loss: 0.7355
# [Epoch 78/200](LR: 0.000063) -> Train Acc: 78.03%, Test Acc: 77.27% | Train Loss: 0.7181
# [Epoch 79/200](LR: 0.000063) -> Train Acc: 77.12%, Test Acc: 77.73% | Train Loss: 0.7316
# [Epoch 80/200](LR: 0.000063) -> Train Acc: 75.00%, Test Acc: 78.18% | Train Loss: 0.7579
# [Epoch 81/200](LR: 0.000063) -> Train Acc: 75.30%, Test Acc: 79.09% | Train Loss: 0.7283
# [Epoch 82/200](LR: 0.000063) -> Train Acc: 80.45%, Test Acc: 77.73% | Train Loss: 0.6548
# [Epoch 83/200](LR: 0.000063) -> Train Acc: 81.21%, Test Acc: 79.09% | Train Loss: 0.6503
# [Epoch 84/200](LR: 0.000063) -> Train Acc: 79.70%, Test Acc: 78.18% | Train Loss: 0.6814
# [Epoch 85/200](LR: 0.000063) -> Train Acc: 78.79%, Test Acc: 77.73% | Train Loss: 0.7307
# [Epoch 86/200](LR: 0.000063) -> Train Acc: 79.70%, Test Acc: 77.27% | Train Loss: 0.6776
# Epoch 00087: reducing learning rate of group 0 to 3.1250e-05.
# [Epoch 87/200](LR: 0.000031) -> Train Acc: 79.39%, Test Acc: 76.36% | Train Loss: 0.6720
# [Epoch 88/200](LR: 0.000031) -> Train Acc: 79.70%, Test Acc: 75.00% | Train Loss: 0.6708
# [Epoch 89/200](LR: 0.000031) -> Train Acc: 79.39%, Test Acc: 78.64% | Train Loss: 0.6608
# [Epoch 90/200](LR: 0.000031) -> Train Acc: 79.85%, Test Acc: 78.64% | Train Loss: 0.6359
# [Epoch 91/200](LR: 0.000031) -> Train Acc: 79.70%, Test Acc: 76.36% | Train Loss: 0.6557
# [Epoch 92/200](LR: 0.000031) -> Train Acc: 82.27%, Test Acc: 77.27% | Train Loss: 0.6162
# Epoch 00093: reducing learning rate of group 0 to 1.5625e-05.
# [Epoch 93/200](LR: 0.000016) -> Train Acc: 80.76%, Test Acc: 79.09% | Train Loss: 0.6043
# [Epoch 94/200](LR: 0.000016) -> Train Acc: 81.06%, Test Acc: 78.18% | Train Loss: 0.5994
# [Epoch 95/200](LR: 0.000016) -> Train Acc: 80.61%, Test Acc: 78.64% | Train Loss: 0.6681
# [Epoch 96/200](LR: 0.000016) -> Train Acc: 80.61%, Test Acc: 76.82% | Train Loss: 0.6352
# [Epoch 97/200](LR: 0.000016) -> Train Acc: 79.55%, Test Acc: 77.73% | Train Loss: 0.6896
# [Epoch 98/200](LR: 0.000016) -> Train Acc: 81.21%, Test Acc: 77.73% | Train Loss: 0.6205
# Epoch 00099: reducing learning rate of group 0 to 7.8125e-06.
# [Epoch 99/200](LR: 0.000008) -> Train Acc: 81.67%, Test Acc: 78.18% | Train Loss: 0.6189
# [Epoch 100/200](LR: 0.000008) -> Train Acc: 81.21%, Test Acc: 76.36% | Train Loss: 0.6194
# [Epoch 101/200](LR: 0.000008) -> Train Acc: 78.48%, Test Acc: 77.27% | Train Loss: 0.6386
# [Epoch 102/200](LR: 0.000008) -> Train Acc: 82.12%, Test Acc: 77.27% | Train Loss: 0.6062
# [Epoch 103/200](LR: 0.000008) -> Train Acc: 83.64%, Test Acc: 78.18% | Train Loss: 0.5523
# [Epoch 104/200](LR: 0.000008) -> Train Acc: 83.03%, Test Acc: 77.27% | Train Loss: 0.5777
# Epoch 00105: reducing learning rate of group 0 to 3.9063e-06.
# [Epoch 105/200](LR: 0.000004) -> Train Acc: 82.73%, Test Acc: 77.73% | Train Loss: 0.5976
# [Epoch 106/200](LR: 0.000004) -> Train Acc: 83.33%, Test Acc: 77.73% | Train Loss: 0.5883
# [Epoch 107/200](LR: 0.000004) -> Train Acc: 82.88%, Test Acc: 77.27% | Train Loss: 0.5893
# [Epoch 108/200](LR: 0.000004) -> Train Acc: 81.67%, Test Acc: 76.82% | Train Loss: 0.6086
# [Epoch 109/200](LR: 0.000004) -> Train Acc: 83.79%, Test Acc: 75.45% | Train Loss: 0.5728
# [Epoch 110/200](LR: 0.000004) -> Train Acc: 82.58%, Test Acc: 76.82% | Train Loss: 0.5734
# Epoch 00111: reducing learning rate of group 0 to 1.9531e-06.
# [Epoch 111/200](LR: 0.000002) -> Train Acc: 82.27%, Test Acc: 77.73% | Train Loss: 0.5782
# [Epoch 112/200](LR: 0.000002) -> Train Acc: 79.70%, Test Acc: 77.27% | Train Loss: 0.6701
# [Epoch 113/200](LR: 0.000002) -> Train Acc: 81.21%, Test Acc: 77.27% | Train Loss: 0.6351
# [Epoch 114/200](LR: 0.000002) -> Train Acc: 81.36%, Test Acc: 76.82% | Train Loss: 0.6143
# [Epoch 115/200](LR: 0.000002) -> Train Acc: 83.64%, Test Acc: 76.36% | Train Loss: 0.5752
# [Epoch 116/200](LR: 0.000002) -> Train Acc: 82.27%, Test Acc: 79.09% | Train Loss: 0.6000
# Epoch 00117: reducing learning rate of group 0 to 9.7656e-07.
# [Epoch 117/200](LR: 0.000001) -> Train Acc: 79.55%, Test Acc: 77.73% | Train Loss: 0.6141
# [Epoch 118/200](LR: 0.000001) -> Train Acc: 83.03%, Test Acc: 77.73% | Train Loss: 0.5976
# [Epoch 119/200](LR: 0.000001) -> Train Acc: 80.91%, Test Acc: 76.82% | Train Loss: 0.6280
# [Epoch 120/200](LR: 0.000001) -> Train Acc: 81.67%, Test Acc: 77.27% | Train Loss: 0.6100
# [Epoch 121/200](LR: 0.000001) -> Train Acc: 81.21%, Test Acc: 77.27% | Train Loss: 0.6251
# [Epoch 122/200](LR: 0.000001) -> Train Acc: 79.70%, Test Acc: 78.18% | Train Loss: 0.6276
# Epoch 00123: reducing learning rate of group 0 to 4.8828e-07.
# [Epoch 123/200](LR: 0.000000) -> Train Acc: 83.48%, Test Acc: 77.27% | Train Loss: 0.5701
# [Epoch 124/200](LR: 0.000000) -> Train Acc: 83.64%, Test Acc: 78.18% | Train Loss: 0.5920
# [Epoch 125/200](LR: 0.000000) -> Train Acc: 78.03%, Test Acc: 78.18% | Train Loss: 0.6635
# [Epoch 126/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 78.18% | Train Loss: 0.6729
# [Epoch 127/200](LR: 0.000000) -> Train Acc: 80.61%, Test Acc: 77.27% | Train Loss: 0.6505
# [Epoch 128/200](LR: 0.000000) -> Train Acc: 79.24%, Test Acc: 78.18% | Train Loss: 0.6861
# Epoch 00129: reducing learning rate of group 0 to 2.4414e-07.
# [Epoch 129/200](LR: 0.000000) -> Train Acc: 82.27%, Test Acc: 76.82% | Train Loss: 0.5985
# [Epoch 130/200](LR: 0.000000) -> Train Acc: 82.73%, Test Acc: 76.82% | Train Loss: 0.5817
# [Epoch 131/200](LR: 0.000000) -> Train Acc: 83.64%, Test Acc: 77.27% | Train Loss: 0.5852
# [Epoch 132/200](LR: 0.000000) -> Train Acc: 80.15%, Test Acc: 77.27% | Train Loss: 0.6321
# [Epoch 133/200](LR: 0.000000) -> Train Acc: 81.21%, Test Acc: 76.82% | Train Loss: 0.6175
# [Epoch 134/200](LR: 0.000000) -> Train Acc: 82.12%, Test Acc: 78.64% | Train Loss: 0.6005
# Epoch 00135: reducing learning rate of group 0 to 1.2207e-07.
# [Epoch 135/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 76.82% | Train Loss: 0.6300
# [Epoch 136/200](LR: 0.000000) -> Train Acc: 79.70%, Test Acc: 77.73% | Train Loss: 0.6604
# [Epoch 137/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 77.27% | Train Loss: 0.5757
# [Epoch 138/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 76.36% | Train Loss: 0.6205
# [Epoch 139/200](LR: 0.000000) -> Train Acc: 83.94%, Test Acc: 77.27% | Train Loss: 0.5528
# [Epoch 140/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 76.82% | Train Loss: 0.6491
# Epoch 00141: reducing learning rate of group 0 to 6.1035e-08.
# [Epoch 141/200](LR: 0.000000) -> Train Acc: 82.12%, Test Acc: 77.27% | Train Loss: 0.5936
# [Epoch 142/200](LR: 0.000000) -> Train Acc: 83.33%, Test Acc: 76.82% | Train Loss: 0.5736
# [Epoch 143/200](LR: 0.000000) -> Train Acc: 80.00%, Test Acc: 78.18% | Train Loss: 0.6418
# [Epoch 144/200](LR: 0.000000) -> Train Acc: 80.30%, Test Acc: 76.82% | Train Loss: 0.6567
# [Epoch 145/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 78.18% | Train Loss: 0.5919
# [Epoch 146/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 77.27% | Train Loss: 0.6017
# Epoch 00147: reducing learning rate of group 0 to 3.0518e-08.
# [Epoch 147/200](LR: 0.000000) -> Train Acc: 80.45%, Test Acc: 76.82% | Train Loss: 0.6348
# [Epoch 148/200](LR: 0.000000) -> Train Acc: 84.39%, Test Acc: 76.82% | Train Loss: 0.5515
# [Epoch 149/200](LR: 0.000000) -> Train Acc: 80.15%, Test Acc: 77.73% | Train Loss: 0.6335
# [Epoch 150/200](LR: 0.000000) -> Train Acc: 81.06%, Test Acc: 77.73% | Train Loss: 0.6403
# [Epoch 151/200](LR: 0.000000) -> Train Acc: 83.79%, Test Acc: 77.27% | Train Loss: 0.6138
# [Epoch 152/200](LR: 0.000000) -> Train Acc: 79.09%, Test Acc: 76.36% | Train Loss: 0.6231
# Epoch 00153: reducing learning rate of group 0 to 1.5259e-08.
# [Epoch 153/200](LR: 0.000000) -> Train Acc: 82.73%, Test Acc: 77.27% | Train Loss: 0.5829
# [Epoch 154/200](LR: 0.000000) -> Train Acc: 82.58%, Test Acc: 77.73% | Train Loss: 0.6135
# [Epoch 155/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 78.18% | Train Loss: 0.6098
# [Epoch 156/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 77.73% | Train Loss: 0.6100
# [Epoch 157/200](LR: 0.000000) -> Train Acc: 85.30%, Test Acc: 79.09% | Train Loss: 0.5379
# [Epoch 158/200](LR: 0.000000) -> Train Acc: 79.85%, Test Acc: 79.09% | Train Loss: 0.6858
# [Epoch 159/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 76.36% | Train Loss: 0.5804
# [Epoch 160/200](LR: 0.000000) -> Train Acc: 81.52%, Test Acc: 77.73% | Train Loss: 0.6453
# [Epoch 161/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 77.27% | Train Loss: 0.5977
# [Epoch 162/200](LR: 0.000000) -> Train Acc: 80.91%, Test Acc: 77.73% | Train Loss: 0.6510
# [Epoch 163/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 77.73% | Train Loss: 0.6095
# [Epoch 164/200](LR: 0.000000) -> Train Acc: 81.67%, Test Acc: 77.27% | Train Loss: 0.6243
# [Epoch 165/200](LR: 0.000000) -> Train Acc: 79.09%, Test Acc: 77.27% | Train Loss: 0.6322
# [Epoch 166/200](LR: 0.000000) -> Train Acc: 83.64%, Test Acc: 78.18% | Train Loss: 0.5580
# [Epoch 167/200](LR: 0.000000) -> Train Acc: 80.61%, Test Acc: 78.18% | Train Loss: 0.6487
# [Epoch 168/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 79.09% | Train Loss: 0.5720
# [Epoch 169/200](LR: 0.000000) -> Train Acc: 83.64%, Test Acc: 78.18% | Train Loss: 0.5657
# [Epoch 170/200](LR: 0.000000) -> Train Acc: 81.21%, Test Acc: 78.18% | Train Loss: 0.6441
# [Epoch 171/200](LR: 0.000000) -> Train Acc: 81.52%, Test Acc: 75.91% | Train Loss: 0.5953
# [Epoch 172/200](LR: 0.000000) -> Train Acc: 83.18%, Test Acc: 76.82% | Train Loss: 0.5593
# [Epoch 173/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 78.18% | Train Loss: 0.6182
# [Epoch 174/200](LR: 0.000000) -> Train Acc: 82.27%, Test Acc: 77.73% | Train Loss: 0.6193
# [Epoch 175/200](LR: 0.000000) -> Train Acc: 79.70%, Test Acc: 76.82% | Train Loss: 0.6418
# [Epoch 176/200](LR: 0.000000) -> Train Acc: 78.94%, Test Acc: 76.82% | Train Loss: 0.6218
# [Epoch 177/200](LR: 0.000000) -> Train Acc: 83.18%, Test Acc: 75.91% | Train Loss: 0.6101
# [Epoch 178/200](LR: 0.000000) -> Train Acc: 77.73%, Test Acc: 78.18% | Train Loss: 0.6775
# [Epoch 179/200](LR: 0.000000) -> Train Acc: 80.61%, Test Acc: 77.27% | Train Loss: 0.6271
# [Epoch 180/200](LR: 0.000000) -> Train Acc: 80.91%, Test Acc: 77.27% | Train Loss: 0.5947
# [Epoch 181/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 78.18% | Train Loss: 0.5586
# [Epoch 182/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 77.73% | Train Loss: 0.5870
# [Epoch 183/200](LR: 0.000000) -> Train Acc: 83.94%, Test Acc: 76.82% | Train Loss: 0.5883
# [Epoch 184/200](LR: 0.000000) -> Train Acc: 78.64%, Test Acc: 76.82% | Train Loss: 0.6250
# [Epoch 185/200](LR: 0.000000) -> Train Acc: 81.67%, Test Acc: 76.36% | Train Loss: 0.6130
# [Epoch 186/200](LR: 0.000000) -> Train Acc: 80.30%, Test Acc: 76.82% | Train Loss: 0.6673
# [Epoch 187/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 77.73% | Train Loss: 0.5889
# [Epoch 188/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 76.82% | Train Loss: 0.5950
# [Epoch 189/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 76.82% | Train Loss: 0.5809
# [Epoch 190/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 75.91% | Train Loss: 0.6092
# [Epoch 191/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 77.73% | Train Loss: 0.6130
# [Epoch 192/200](LR: 0.000000) -> Train Acc: 82.88%, Test Acc: 77.73% | Train Loss: 0.5811
# [Epoch 193/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 77.27% | Train Loss: 0.6022
# [Epoch 194/200](LR: 0.000000) -> Train Acc: 82.27%, Test Acc: 76.82% | Train Loss: 0.6034
# [Epoch 195/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 78.64% | Train Loss: 0.5745
# [Epoch 196/200](LR: 0.000000) -> Train Acc: 83.18%, Test Acc: 76.82% | Train Loss: 0.5814
# [Epoch 197/200](LR: 0.000000) -> Train Acc: 82.88%, Test Acc: 77.27% | Train Loss: 0.5904
# [Epoch 198/200](LR: 0.000000) -> Train Acc: 83.94%, Test Acc: 76.82% | Train Loss: 0.5845
# [Epoch 199/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 77.73% | Train Loss: 0.6653
# [Epoch 200/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 77.27% | Train Loss: 0.6050
