# %% [markdown]
# # Flexible CNN模型 - 使用Optuna得到的最优参数
# 参数：1889070
# #### Best trial:
# Best trial:                     \
#   Value: 80.9091                \
#   Params:
#     n_layers: 6
#     n_filters_layer0: 32
#     kernel_size_layer0: 3
#     n_filters_layer1: 32
#     kernel_size_layer1: 3
#     n_filters_layer2: 32
#     kernel_size_layer2: 3
#     n_filters_layer3: 128
#     kernel_size_layer3: 3
#     n_filters_layer4: 512
#     kernel_size_layer4: 5
#     n_filters_layer5: 32
#     kernel_size_layer5: 5
#     dropout_rate: 0.3495822457727959
#     fc_size: 1024
#     batch_size: 16

# %% [markdown]
# 1. 采用**分层采样**：“每个手指固定 6 张训练、2 张测试”
# 能确保模型在训练时见过每一个手指，在测试时也能评估每一个手指。
# 2. 训练集：测试集 = 6:2，保持了合理的训练数据量，同时保证了测试的代表性。
# 3. **使用LR=0.001并进行学习率衰退**

# %% [markdown]
# **Result: 89.09%的测试准确率**，较未搜索之前的86%有一定提升

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
import matplotlib.pyplot as plt
from PIL import Image
from tqdm.auto import tqdm

from torch.utils.data import Subset
from collections import defaultdict
import random

# %%
BATCH_SIZE = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1. 读取指纹数据

# %%
class FVC2002Dataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        # 过滤出所有的 .tif 文件
        self.image_files = [f for f in os.listdir(root_dir) if f.endswith('.tif')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.root_dir, img_name)
        
        # 加载图像并转为灰度图（指纹图通常是单通道）
        image = Image.open(img_path).convert('L')
        
        # 解析标签：例如 "10_3.tif" -> 标签为 10
        # 注意：类别索引通常从 0 开始，所以我们将 ID 减 1
        label = int(img_name.split('_')[0]) - 1
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# %% [markdown]
# #### 计算数据集的std和mean

# %%
# 临时加载数据集（仅 ToTensor）
dataset = FVC2002Dataset(root_dir='../FVC2002/Db1',
                        transform=transforms.Compose([
                        transforms.Grayscale(),
                        transforms.ToTensor()
                               ]))
loader = DataLoader(dataset, batch_size=100, shuffle=False)

# def get_mean_and_std(loader):
#     mean = 0.
#     std = 0.
#     total_images_count = 0
#     for images, _ in loader:
#         image_count_in_batch = images.size(0)
#         images = images.view(image_count_in_batch, images.size(1), -1)
#         mean += images.mean(2).sum(0)
#         std += images.std(2).sum(0)
#         total_images_count += image_count_in_batch
#     mean /= total_images_count
#     std /= total_images_count
#     return mean, std

# mean, std = get_mean_and_std(loader)
# print(f"Mean: {mean}, Std: {std}")

def calculate_mean_std(dataset):
    """
    Calculates the mean and standard deviation of a PyTorch dataset.

    Args:
        dataset (torch.utils.data.Dataset): The dataset for which to
                                            calculate the stats. It should
                                            return image tensors.

    Returns:
        (torch.Tensor, torch.Tensor): A tuple containing the mean and
                                      standard deviation tensors, each of
                                      shape (C,).
    """
    # Create a DataLoader to iterate through the dataset in batches for efficiency.
    # shuffle=False because the order of images doesn't matter for this calculation.
    loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=0)

    # Initialize tensors to store the sum of pixel values for each (RGB) channel.
    channel_sum = torch.zeros(1)
    # Initialize tensors to store the sum of squared pixel values for each channel.
    channel_sum_sq = torch.zeros(1)
    # Initialize a counter for the total number of pixels.
    num_pixels = 0

    # Wrap the loader with tqdm to create a progress bar for monitoring.
    for images, _ in tqdm(loader, desc="Calculating Dataset Stats"):
        # Add the total number of pixels in this batch to the running total.
        num_pixels += images.size(0) * images.size(2) * images.size(3)
        
        # Sum the pixel values across the batch, height, and width dimensions,
        # leaving only the channel dimension. Add this to the running total.
        channel_sum += images.sum(dim=[0, 2, 3])
        
        # Square each pixel value, then sum them up similarly to the step above.
        channel_sum_sq += (images ** 2).sum(dim=[0, 2, 3])

    # Calculate the mean for each channel.
    mean = channel_sum / num_pixels
    # Calculate the standard deviation using the formula: sqrt(E[X^2] - E[X]^2)
    std = (channel_sum_sq / num_pixels - mean ** 2) ** 0.5

    # Return the calculated mean and standard deviation.
    return mean, std

mean, std = calculate_mean_std(dataset)
print(f"Mean: {mean}, Std: {std}")
# Out:
# Calculating Dataset Stats:   0%|          | 0/14 [00:00<?, ?it/s]
# Mean: tensor([0.8499]), Std: tensor([0.2547])

# %%
# 指纹图片查看
def visualize_fvc_samples(dataset, num_people=2, samples_per_person=5):
    # 1. 建立 ID 到 索引列表的映射
    # label 是 img_name.split('_')[0] - 1
    id_to_indices = {}
    for idx, img_name in enumerate(dataset.image_files):
        label = int(img_name.split('_')[0]) - 1
        if label not in id_to_indices:
            id_to_indices[label] = []
        id_to_indices[label].append(idx)

    # 2. 随机抽取指定数量的人
    selected_ids = random.sample(list(id_to_indices.keys()), num_people)

    # 3. 开始绘图
    fig, axes = plt.subplots(num_people, samples_per_person, figsize=(15, 6), dpi=300)
    fig.suptitle('FVC2002 Fingerprint Samples Visualization', fontsize=16)

    for i, person_id in enumerate(selected_ids):
        # 随机抽取该人的 5 个指纹索引
        indices = random.sample(id_to_indices[person_id], samples_per_person)
        
        for j, idx in enumerate(indices):
            image, label = dataset[idx]
            
            # 如果 image 是 Tensor (经过了 transform)，需要转回 numpy
            if torch.is_tensor(image):
                image = image.squeeze().numpy() # 移除通道维度 [1, H, W] -> [H, W]
            
            ax = axes[i, j] if num_people > 1 else axes[j]
            ax.imshow(image, cmap='gray')
            ax.set_title(f"ID: {person_id + 1}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# 使用方法：
visualize_fvc_samples(dataset, num_people=2, samples_per_person=5)

# %%
class ApplyTransform(Dataset):
    """
    一个简单的装饰器类，用于给 Subset 应用特定的 transform
    """
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
        
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
        
    def __len__(self):
        return len(self.subset)

# 1. 定义两个不同的 Pipeline
# 基础操作（训练和测试共有）
base_ops = [
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.85], std=[0.2375])
]

# 训练集特有：加入随机旋转
train_transforms = transforms.Compose([
    transforms.RandomRotation(15),
    *base_ops
])

# 测试集：仅基础操作
test_transforms = transforms.Compose(base_ops)

# 2. 原始数据集加载时不带 transform (或者只带 Resize)
full_dataset = FVC2002Dataset(root_dir='../FVC2002/Db1', transform=None)

# --- 2. 建立标签到索引的映射 (字典结构) ---
# 这一步是为了找出每个手指对应的 8 张图分别在列表的哪个位置
label_to_indices = defaultdict(list)
for idx, img_name in enumerate(full_dataset.image_files):
    # 使用与你 Dataset 类中一致的解析逻辑
    label = int(img_name.split('_')[0]) - 1
    label_to_indices[label].append(idx)

train_indices = []
test_indices = []

# --- 3. 核心：对每一个类别固定分配 6/2 ---
# 确保每个类（手指）都参与了划分
for label, indices in label_to_indices.items():
    # 随机打乱当前手指的 8 张图索引
    random.shuffle(indices)
    
    # 取前 6 张作为训练，后 2 张作为测试
    train_indices.extend(indices[:6])
    test_indices.extend(indices[6:])

# --- 4. 创建 Subset 并应用不同的 Transform ---
# 先利用索引创建子集
train_subset = Subset(full_dataset, train_indices)
test_subset = Subset(full_dataset, test_indices)
# 5. 分别包装，应用不同的 transform
train_dataset = ApplyTransform(train_subset, transform=train_transforms)
test_dataset = ApplyTransform(test_subset, transform=test_transforms)

# %%
len(train_dataset), len(test_dataset)
# Out:
# (660, 220)

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ## 2. 构建模型

# %%
# 设计一个灵活的 CNN 模型，允许用户指定卷积层数、每层的滤波器数量、卷积核大小、Dropout率、全连接层大小等超参数
# 在训练之前需要进行一次dummy forward，来根据卷积层的输出特征图大小自动计算全连接层的输入维度

class FlexibleCNN(nn.Module):
    def __init__(self, input_shape, n_layers, n_filters, kernel_sizes, dropout_rate, fc_size, num_classes):
        super(FlexibleCNN, self).__init__()
        blocks = []
        in_channels = input_shape[0] # grey fingerprint

        for i in range(n_layers):
            out_channels = n_filters[i]
            kernel_size = kernel_sizes[i]
            padding = kernel_size // 2 # 保持尺寸不变
            
            block = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)
            )
            blocks.append(block)
            in_channels = out_channels

        self.features = nn.Sequential(*blocks)

        # --- 加入全局平均池化层 ---
        # 无论特征图多大，都压缩成 (batch, channels, 1, 1)
        self.gap = nn.AdaptiveAvgPool2d((1, 1))

        # 2. 执行 Dummy Forward 以计算全连接层的输入尺寸
        self.flattened_size = self._get_conv_output_shape(input_shape)

        # 3. 构建分类器 (在 __init__ 中完成，确保参数被注册)
        self.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.flattened_size, fc_size),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(fc_size, num_classes)
        )


    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)  # 应用全局平均池化
        x = torch.flatten(x, 1) # 展平为 (batch_size, flattened_size)
        x = self.classifier(x)
        return x
    
    def _get_conv_output_shape(self, shape):
        with torch.no_grad():
            batch_size = 1
            dummy_input = torch.ones(batch_size, *shape)
            output_tensor = self.features(dummy_input)
            output_tensor = self.gap(output_tensor)  # 应用全局平均池化
            output_size = output_tensor.view(batch_size, -1).size(1)
            return output_size

def get_flexible_cnn(num_classes=110):
    input_shape = (1, 224, 224) # 单通道输入，224x224
    n_layers = 6
    n_filters = [32, 32, 32, 128, 512, 32]
    kernel_sizes = [3, 3, 3, 3, 5, 5]
    dropout_rate = 0.34958
    fc_size = 1024
    
    model = FlexibleCNN(input_shape, n_layers, n_filters, kernel_sizes, dropout_rate, fc_size, num_classes)
    return model

# %% [markdown]
# ## 3. 模型训练

# %%
# 1. 训练一个 Epoch 的函数
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
    train_loss = running_loss / len(loader)
    train_acc = 100. * correct / total
    return train_loss, train_acc

# %%
# 2. 验证/测试函数 (基于你提供的 evaluate 修改)
def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            
    val_loss = running_loss / len(loader)
    val_acc = 100. * correct / total
    return val_loss, val_acc

# %%
# 3. 总训练控制函数
def train(model, train_loader, test_loader, criterion, optimizer, device, scheduler=None, epochs=20):
    # 用于记录历史数据以便绘图
    history = {
        'train_loss': [], 'train_acc': [],
        'test_loss': [], 'test_acc': []
    }
    
    print(f"开始训练，设备: {device}")
    for epoch in range(epochs):
        # 训练阶段
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        # 验证阶段
        test_loss, test_acc = validate(model, test_loader, criterion, device)
        
        # 每个 epoch 结束更新学习率
        if scheduler is not None:
            if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_acc)  # 以验证准确率为指标调整学习率
            else:
                scheduler.step()  # 其他类型的调度器直接调用 step()
            current_lr = optimizer.param_groups[0]['lr']

        # 记录历史
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        
        print(f"[Epoch {epoch+1}/{epochs}](LR: {current_lr:.6f}) -> "
              f"Train Acc: {train_acc:.2f}%, Test Acc: {test_acc:.2f}% | "
              f"Train Loss: {train_loss:.4f}")

    # 训练结束后进行可视化
    plot_history(history)
    return history

# 4. 可视化函数
def plot_history(history):
    epochs = range(1, len(history['train_acc']) + 1)
    
    plt.figure(figsize=(12, 5))
    
    # 绘制准确率曲线
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Acc')
    plt.plot(epochs, history['test_acc'], 'r-', label='Test Acc')
    plt.title('Training and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    
    # 绘制损失曲线
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['test_loss'], 'r-', label='Test Loss')
    plt.title('Training and Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.1 ResNet18

# %% [markdown]
# ### 3.1.1 预训练模型

# %% [markdown]
# ##### 余弦退火

# %%
flexible_cnn = get_flexible_cnn(num_classes=110).to(device)
optimizer = optim.Adam(flexible_cnn.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=300, eta_min=1e-5)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in flexible_cnn.parameters())
print(f"总参数量: {total_params:,}")
history1 = train(flexible_cnn, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=300)
# Out:
# 总参数量: 2,252,430
# 开始训练，设备: cuda
# [Epoch 1/300](LR: 0.001000) -> Train Acc: 0.61%, Test Acc: 1.36% | Train Loss: 4.8540
# [Epoch 2/300](LR: 0.001000) -> Train Acc: 1.21%, Test Acc: 2.27% | Train Loss: 4.6189
# [Epoch 3/300](LR: 0.001000) -> Train Acc: 3.33%, Test Acc: 4.55% | Train Loss: 4.4424
# [Epoch 4/300](LR: 0.001000) -> Train Acc: 4.09%, Test Acc: 7.73% | Train Loss: 4.2660
# [Epoch 5/300](LR: 0.000999) -> Train Acc: 3.79%, Test Acc: 6.82% | Train Loss: 4.0947
# [Epoch 6/300](LR: 0.000999) -> Train Acc: 6.36%, Test Acc: 5.45% | Train Loss: 3.9200
# [Epoch 7/300](LR: 0.000999) -> Train Acc: 8.94%, Test Acc: 2.73% | Train Loss: 3.8481
# [Epoch 8/300](LR: 0.000998) -> Train Acc: 8.33%, Test Acc: 12.73% | Train Loss: 3.7127
# [Epoch 9/300](LR: 0.000998) -> Train Acc: 9.55%, Test Acc: 13.18% | Train Loss: 3.5590
# [Epoch 10/300](LR: 0.000997) -> Train Acc: 11.36%, Test Acc: 10.91% | Train Loss: 3.4378
# [Epoch 11/300](LR: 0.000997) -> Train Acc: 12.27%, Test Acc: 15.91% | Train Loss: 3.3398
# [Epoch 12/300](LR: 0.000996) -> Train Acc: 14.39%, Test Acc: 15.45% | Train Loss: 3.2596
# [Epoch 13/300](LR: 0.000995) -> Train Acc: 16.21%, Test Acc: 12.27% | Train Loss: 3.1346
# [Epoch 14/300](LR: 0.000995) -> Train Acc: 15.61%, Test Acc: 22.73% | Train Loss: 3.0971
# [Epoch 15/300](LR: 0.000994) -> Train Acc: 17.73%, Test Acc: 20.91% | Train Loss: 2.9576
# [Epoch 16/300](LR: 0.000993) -> Train Acc: 19.24%, Test Acc: 15.00% | Train Loss: 3.0172
# [Epoch 17/300](LR: 0.000992) -> Train Acc: 19.55%, Test Acc: 28.18% | Train Loss: 2.9651
# [Epoch 18/300](LR: 0.000991) -> Train Acc: 21.06%, Test Acc: 19.09% | Train Loss: 2.9021
# [Epoch 19/300](LR: 0.000990) -> Train Acc: 22.12%, Test Acc: 20.91% | Train Loss: 2.8399
# [Epoch 20/300](LR: 0.000989) -> Train Acc: 23.18%, Test Acc: 29.09% | Train Loss: 2.6921
# [Epoch 21/300](LR: 0.000988) -> Train Acc: 25.76%, Test Acc: 38.64% | Train Loss: 2.5963
# [Epoch 22/300](LR: 0.000987) -> Train Acc: 28.94%, Test Acc: 33.64% | Train Loss: 2.5725
# [Epoch 23/300](LR: 0.000986) -> Train Acc: 26.06%, Test Acc: 33.64% | Train Loss: 2.5660
# [Epoch 24/300](LR: 0.000984) -> Train Acc: 28.79%, Test Acc: 35.45% | Train Loss: 2.4926
# [Epoch 25/300](LR: 0.000983) -> Train Acc: 29.24%, Test Acc: 39.55% | Train Loss: 2.3693
# [Epoch 26/300](LR: 0.000982) -> Train Acc: 33.33%, Test Acc: 28.18% | Train Loss: 2.3807
# [Epoch 27/300](LR: 0.000980) -> Train Acc: 31.97%, Test Acc: 41.36% | Train Loss: 2.3077
# [Epoch 28/300](LR: 0.000979) -> Train Acc: 34.85%, Test Acc: 24.09% | Train Loss: 2.2323
# [Epoch 29/300](LR: 0.000977) -> Train Acc: 36.21%, Test Acc: 53.18% | Train Loss: 2.1248
# [Epoch 30/300](LR: 0.000976) -> Train Acc: 38.94%, Test Acc: 48.64% | Train Loss: 2.0325
# [Epoch 31/300](LR: 0.000974) -> Train Acc: 41.36%, Test Acc: 49.55% | Train Loss: 2.0240
# [Epoch 32/300](LR: 0.000972) -> Train Acc: 38.79%, Test Acc: 48.18% | Train Loss: 2.0011
# [Epoch 33/300](LR: 0.000971) -> Train Acc: 41.97%, Test Acc: 50.00% | Train Loss: 2.0386
# [Epoch 34/300](LR: 0.000969) -> Train Acc: 43.48%, Test Acc: 50.45% | Train Loss: 1.8947
# [Epoch 35/300](LR: 0.000967) -> Train Acc: 40.45%, Test Acc: 41.82% | Train Loss: 1.9150
# [Epoch 36/300](LR: 0.000965) -> Train Acc: 47.42%, Test Acc: 47.27% | Train Loss: 1.8346
# [Epoch 37/300](LR: 0.000963) -> Train Acc: 45.00%, Test Acc: 47.73% | Train Loss: 1.8009
# [Epoch 38/300](LR: 0.000961) -> Train Acc: 50.00%, Test Acc: 50.91% | Train Loss: 1.6944
# [Epoch 39/300](LR: 0.000959) -> Train Acc: 44.55%, Test Acc: 45.91% | Train Loss: 1.8430
# [Epoch 40/300](LR: 0.000957) -> Train Acc: 49.55%, Test Acc: 60.00% | Train Loss: 1.6274
# [Epoch 41/300](LR: 0.000955) -> Train Acc: 51.52%, Test Acc: 57.27% | Train Loss: 1.6368
# [Epoch 42/300](LR: 0.000953) -> Train Acc: 51.36%, Test Acc: 59.09% | Train Loss: 1.5888
# [Epoch 43/300](LR: 0.000951) -> Train Acc: 49.09%, Test Acc: 59.09% | Train Loss: 1.6635
# [Epoch 44/300](LR: 0.000948) -> Train Acc: 52.88%, Test Acc: 59.55% | Train Loss: 1.5703
# [Epoch 45/300](LR: 0.000946) -> Train Acc: 55.76%, Test Acc: 64.09% | Train Loss: 1.4723
# [Epoch 46/300](LR: 0.000944) -> Train Acc: 53.33%, Test Acc: 61.36% | Train Loss: 1.5214
# [Epoch 47/300](LR: 0.000941) -> Train Acc: 55.15%, Test Acc: 56.36% | Train Loss: 1.4298
# [Epoch 48/300](LR: 0.000939) -> Train Acc: 58.03%, Test Acc: 66.36% | Train Loss: 1.4876
# [Epoch 49/300](LR: 0.000936) -> Train Acc: 55.76%, Test Acc: 63.64% | Train Loss: 1.4623
# [Epoch 50/300](LR: 0.000934) -> Train Acc: 53.79%, Test Acc: 64.09% | Train Loss: 1.4493
# [Epoch 51/300](LR: 0.000931) -> Train Acc: 57.88%, Test Acc: 70.00% | Train Loss: 1.3485
# [Epoch 52/300](LR: 0.000928) -> Train Acc: 56.67%, Test Acc: 70.45% | Train Loss: 1.3560
# [Epoch 53/300](LR: 0.000926) -> Train Acc: 57.73%, Test Acc: 66.82% | Train Loss: 1.3339
# [Epoch 54/300](LR: 0.000923) -> Train Acc: 62.58%, Test Acc: 67.73% | Train Loss: 1.2952
# [Epoch 55/300](LR: 0.000920) -> Train Acc: 61.36%, Test Acc: 65.45% | Train Loss: 1.2262
# [Epoch 56/300](LR: 0.000917) -> Train Acc: 61.06%, Test Acc: 65.00% | Train Loss: 1.1985
# [Epoch 57/300](LR: 0.000914) -> Train Acc: 63.79%, Test Acc: 67.73% | Train Loss: 1.1261
# [Epoch 58/300](LR: 0.000911) -> Train Acc: 63.79%, Test Acc: 70.45% | Train Loss: 1.1918
# [Epoch 59/300](LR: 0.000908) -> Train Acc: 65.00%, Test Acc: 70.00% | Train Loss: 1.1604
# [Epoch 60/300](LR: 0.000905) -> Train Acc: 67.12%, Test Acc: 75.45% | Train Loss: 1.0817
# [Epoch 61/300](LR: 0.000902) -> Train Acc: 63.03%, Test Acc: 70.00% | Train Loss: 1.1718
# [Epoch 62/300](LR: 0.000899) -> Train Acc: 62.73%, Test Acc: 71.82% | Train Loss: 1.2236
# [Epoch 63/300](LR: 0.000896) -> Train Acc: 68.03%, Test Acc: 72.73% | Train Loss: 1.0822
# [Epoch 64/300](LR: 0.000893) -> Train Acc: 67.27%, Test Acc: 69.55% | Train Loss: 1.0207
# [Epoch 65/300](LR: 0.000890) -> Train Acc: 70.61%, Test Acc: 73.64% | Train Loss: 0.9265
# [Epoch 66/300](LR: 0.000886) -> Train Acc: 70.30%, Test Acc: 73.18% | Train Loss: 0.9819
# [Epoch 67/300](LR: 0.000883) -> Train Acc: 72.12%, Test Acc: 74.09% | Train Loss: 0.8946
# [Epoch 68/300](LR: 0.000880) -> Train Acc: 71.97%, Test Acc: 77.27% | Train Loss: 0.9235
# [Epoch 69/300](LR: 0.000876) -> Train Acc: 69.39%, Test Acc: 73.64% | Train Loss: 0.9616
# [Epoch 70/300](LR: 0.000873) -> Train Acc: 66.97%, Test Acc: 73.64% | Train Loss: 1.0502
# [Epoch 71/300](LR: 0.000869) -> Train Acc: 69.85%, Test Acc: 74.55% | Train Loss: 0.9662
# [Epoch 72/300](LR: 0.000866) -> Train Acc: 72.58%, Test Acc: 75.45% | Train Loss: 0.8706
# [Epoch 73/300](LR: 0.000862) -> Train Acc: 73.18%, Test Acc: 75.00% | Train Loss: 0.8728
# [Epoch 74/300](LR: 0.000859) -> Train Acc: 70.30%, Test Acc: 75.91% | Train Loss: 0.9159
# [Epoch 75/300](LR: 0.000855) -> Train Acc: 73.18%, Test Acc: 75.45% | Train Loss: 0.8152
# [Epoch 76/300](LR: 0.000851) -> Train Acc: 70.00%, Test Acc: 74.55% | Train Loss: 0.9591
# [Epoch 77/300](LR: 0.000848) -> Train Acc: 72.42%, Test Acc: 73.64% | Train Loss: 0.8585
# [Epoch 78/300](LR: 0.000844) -> Train Acc: 76.52%, Test Acc: 76.36% | Train Loss: 0.8255
# [Epoch 79/300](LR: 0.000840) -> Train Acc: 72.73%, Test Acc: 79.09% | Train Loss: 0.8639
# [Epoch 80/300](LR: 0.000836) -> Train Acc: 71.06%, Test Acc: 74.09% | Train Loss: 0.8792
# [Epoch 81/300](LR: 0.000832) -> Train Acc: 75.30%, Test Acc: 76.36% | Train Loss: 0.7704
# [Epoch 82/300](LR: 0.000828) -> Train Acc: 73.79%, Test Acc: 78.64% | Train Loss: 0.8385
# [Epoch 83/300](LR: 0.000825) -> Train Acc: 75.00%, Test Acc: 79.09% | Train Loss: 0.7885
# [Epoch 84/300](LR: 0.000821) -> Train Acc: 74.24%, Test Acc: 72.27% | Train Loss: 0.7556
# [Epoch 85/300](LR: 0.000817) -> Train Acc: 75.00%, Test Acc: 77.73% | Train Loss: 0.7777
# [Epoch 86/300](LR: 0.000812) -> Train Acc: 76.36%, Test Acc: 76.82% | Train Loss: 0.7230
# [Epoch 87/300](LR: 0.000808) -> Train Acc: 79.85%, Test Acc: 82.73% | Train Loss: 0.6837
# [Epoch 88/300](LR: 0.000804) -> Train Acc: 76.97%, Test Acc: 77.73% | Train Loss: 0.7187
# [Epoch 89/300](LR: 0.000800) -> Train Acc: 77.27%, Test Acc: 71.82% | Train Loss: 0.7156
# [Epoch 90/300](LR: 0.000796) -> Train Acc: 78.79%, Test Acc: 75.91% | Train Loss: 0.6828
# [Epoch 91/300](LR: 0.000792) -> Train Acc: 75.61%, Test Acc: 80.45% | Train Loss: 0.7701
# [Epoch 92/300](LR: 0.000788) -> Train Acc: 81.52%, Test Acc: 79.09% | Train Loss: 0.6443
# [Epoch 93/300](LR: 0.000783) -> Train Acc: 78.64%, Test Acc: 78.18% | Train Loss: 0.6910
# [Epoch 94/300](LR: 0.000779) -> Train Acc: 78.64%, Test Acc: 78.64% | Train Loss: 0.6902
# [Epoch 95/300](LR: 0.000775) -> Train Acc: 80.30%, Test Acc: 79.55% | Train Loss: 0.6141
# [Epoch 96/300](LR: 0.000770) -> Train Acc: 79.09%, Test Acc: 76.82% | Train Loss: 0.6527
# [Epoch 97/300](LR: 0.000766) -> Train Acc: 80.30%, Test Acc: 79.09% | Train Loss: 0.6042
# [Epoch 98/300](LR: 0.000761) -> Train Acc: 78.79%, Test Acc: 80.00% | Train Loss: 0.6593
# [Epoch 99/300](LR: 0.000757) -> Train Acc: 83.18%, Test Acc: 79.55% | Train Loss: 0.5607
# [Epoch 100/300](LR: 0.000752) -> Train Acc: 79.24%, Test Acc: 80.91% | Train Loss: 0.6296
# [Epoch 101/300](LR: 0.000748) -> Train Acc: 78.94%, Test Acc: 78.64% | Train Loss: 0.6785
# [Epoch 102/300](LR: 0.000743) -> Train Acc: 82.42%, Test Acc: 79.55% | Train Loss: 0.5469
# [Epoch 103/300](LR: 0.000739) -> Train Acc: 81.97%, Test Acc: 82.27% | Train Loss: 0.5976
# [Epoch 104/300](LR: 0.000734) -> Train Acc: 81.52%, Test Acc: 80.00% | Train Loss: 0.5568
# [Epoch 105/300](LR: 0.000730) -> Train Acc: 81.21%, Test Acc: 80.91% | Train Loss: 0.5813
# [Epoch 106/300](LR: 0.000725) -> Train Acc: 81.82%, Test Acc: 81.82% | Train Loss: 0.5642
# [Epoch 107/300](LR: 0.000720) -> Train Acc: 82.42%, Test Acc: 77.73% | Train Loss: 0.5423
# [Epoch 108/300](LR: 0.000716) -> Train Acc: 82.58%, Test Acc: 82.27% | Train Loss: 0.5706
# [Epoch 109/300](LR: 0.000711) -> Train Acc: 82.58%, Test Acc: 82.73% | Train Loss: 0.5398
# [Epoch 110/300](LR: 0.000706) -> Train Acc: 80.30%, Test Acc: 79.09% | Train Loss: 0.5998
# [Epoch 111/300](LR: 0.000702) -> Train Acc: 81.36%, Test Acc: 82.73% | Train Loss: 0.5496
# [Epoch 112/300](LR: 0.000697) -> Train Acc: 82.73%, Test Acc: 80.45% | Train Loss: 0.5683
# [Epoch 113/300](LR: 0.000692) -> Train Acc: 82.42%, Test Acc: 80.91% | Train Loss: 0.5765
# [Epoch 114/300](LR: 0.000687) -> Train Acc: 83.18%, Test Acc: 82.27% | Train Loss: 0.4956
# [Epoch 115/300](LR: 0.000682) -> Train Acc: 83.94%, Test Acc: 80.91% | Train Loss: 0.5025
# [Epoch 116/300](LR: 0.000678) -> Train Acc: 83.64%, Test Acc: 82.27% | Train Loss: 0.5068
# [Epoch 117/300](LR: 0.000673) -> Train Acc: 83.33%, Test Acc: 82.27% | Train Loss: 0.5190
# [Epoch 118/300](LR: 0.000668) -> Train Acc: 83.94%, Test Acc: 79.55% | Train Loss: 0.5270
# [Epoch 119/300](LR: 0.000663) -> Train Acc: 85.76%, Test Acc: 83.18% | Train Loss: 0.4664
# [Epoch 120/300](LR: 0.000658) -> Train Acc: 83.48%, Test Acc: 82.73% | Train Loss: 0.5310
# [Epoch 121/300](LR: 0.000653) -> Train Acc: 84.39%, Test Acc: 85.45% | Train Loss: 0.4682
# [Epoch 122/300](LR: 0.000648) -> Train Acc: 85.76%, Test Acc: 79.09% | Train Loss: 0.4618
# [Epoch 123/300](LR: 0.000643) -> Train Acc: 87.27%, Test Acc: 80.91% | Train Loss: 0.4394
# [Epoch 124/300](LR: 0.000638) -> Train Acc: 87.27%, Test Acc: 82.73% | Train Loss: 0.4055
# [Epoch 125/300](LR: 0.000633) -> Train Acc: 82.73%, Test Acc: 78.64% | Train Loss: 0.4966
# [Epoch 126/300](LR: 0.000628) -> Train Acc: 86.21%, Test Acc: 82.73% | Train Loss: 0.4242
# [Epoch 127/300](LR: 0.000623) -> Train Acc: 85.45%, Test Acc: 83.64% | Train Loss: 0.4317
# [Epoch 128/300](LR: 0.000618) -> Train Acc: 86.82%, Test Acc: 83.18% | Train Loss: 0.4426
# [Epoch 129/300](LR: 0.000613) -> Train Acc: 88.64%, Test Acc: 84.55% | Train Loss: 0.3767
# [Epoch 130/300](LR: 0.000608) -> Train Acc: 84.85%, Test Acc: 85.00% | Train Loss: 0.4601
# [Epoch 131/300](LR: 0.000603) -> Train Acc: 85.91%, Test Acc: 85.00% | Train Loss: 0.4381
# [Epoch 132/300](LR: 0.000598) -> Train Acc: 84.55%, Test Acc: 82.73% | Train Loss: 0.4616
# [Epoch 133/300](LR: 0.000593) -> Train Acc: 85.76%, Test Acc: 83.64% | Train Loss: 0.4763
# [Epoch 134/300](LR: 0.000588) -> Train Acc: 84.09%, Test Acc: 84.55% | Train Loss: 0.4642
# [Epoch 135/300](LR: 0.000582) -> Train Acc: 87.27%, Test Acc: 83.18% | Train Loss: 0.4026
# [Epoch 136/300](LR: 0.000577) -> Train Acc: 84.85%, Test Acc: 83.18% | Train Loss: 0.4331
# [Epoch 137/300](LR: 0.000572) -> Train Acc: 88.33%, Test Acc: 86.36% | Train Loss: 0.3587
# [Epoch 138/300](LR: 0.000567) -> Train Acc: 90.61%, Test Acc: 84.55% | Train Loss: 0.3581
# [Epoch 139/300](LR: 0.000562) -> Train Acc: 84.39%, Test Acc: 84.55% | Train Loss: 0.4702
# [Epoch 140/300](LR: 0.000557) -> Train Acc: 88.33%, Test Acc: 85.00% | Train Loss: 0.3534
# [Epoch 141/300](LR: 0.000552) -> Train Acc: 90.30%, Test Acc: 84.55% | Train Loss: 0.3328
# [Epoch 142/300](LR: 0.000546) -> Train Acc: 86.67%, Test Acc: 84.55% | Train Loss: 0.3880
# [Epoch 143/300](LR: 0.000541) -> Train Acc: 88.03%, Test Acc: 84.55% | Train Loss: 0.4213
# [Epoch 144/300](LR: 0.000536) -> Train Acc: 86.82%, Test Acc: 85.00% | Train Loss: 0.4052
# [Epoch 145/300](LR: 0.000531) -> Train Acc: 87.58%, Test Acc: 83.64% | Train Loss: 0.3743
# [Epoch 146/300](LR: 0.000526) -> Train Acc: 86.82%, Test Acc: 83.64% | Train Loss: 0.4572
# [Epoch 147/300](LR: 0.000521) -> Train Acc: 89.09%, Test Acc: 84.55% | Train Loss: 0.3670
# [Epoch 148/300](LR: 0.000515) -> Train Acc: 89.70%, Test Acc: 84.55% | Train Loss: 0.3508
# [Epoch 149/300](LR: 0.000510) -> Train Acc: 90.15%, Test Acc: 86.36% | Train Loss: 0.3136
# [Epoch 150/300](LR: 0.000505) -> Train Acc: 91.21%, Test Acc: 83.64% | Train Loss: 0.3159
# [Epoch 151/300](LR: 0.000500) -> Train Acc: 88.64%, Test Acc: 81.82% | Train Loss: 0.3710
# [Epoch 152/300](LR: 0.000495) -> Train Acc: 88.18%, Test Acc: 83.64% | Train Loss: 0.4027
# [Epoch 153/300](LR: 0.000489) -> Train Acc: 88.18%, Test Acc: 82.73% | Train Loss: 0.3654
# [Epoch 154/300](LR: 0.000484) -> Train Acc: 87.42%, Test Acc: 83.64% | Train Loss: 0.3391
# [Epoch 155/300](LR: 0.000479) -> Train Acc: 89.85%, Test Acc: 86.36% | Train Loss: 0.3083
# [Epoch 156/300](LR: 0.000474) -> Train Acc: 87.88%, Test Acc: 85.00% | Train Loss: 0.3694
# [Epoch 157/300](LR: 0.000469) -> Train Acc: 87.88%, Test Acc: 87.27% | Train Loss: 0.3914
# [Epoch 158/300](LR: 0.000464) -> Train Acc: 87.58%, Test Acc: 86.82% | Train Loss: 0.3708
# [Epoch 159/300](LR: 0.000458) -> Train Acc: 88.94%, Test Acc: 87.73% | Train Loss: 0.3401
# [Epoch 160/300](LR: 0.000453) -> Train Acc: 91.21%, Test Acc: 86.82% | Train Loss: 0.2677
# [Epoch 161/300](LR: 0.000448) -> Train Acc: 91.67%, Test Acc: 85.45% | Train Loss: 0.2707
# [Epoch 162/300](LR: 0.000443) -> Train Acc: 90.91%, Test Acc: 85.00% | Train Loss: 0.3288
# [Epoch 163/300](LR: 0.000438) -> Train Acc: 89.09%, Test Acc: 86.82% | Train Loss: 0.3679
# [Epoch 164/300](LR: 0.000433) -> Train Acc: 89.39%, Test Acc: 86.36% | Train Loss: 0.3500
# [Epoch 165/300](LR: 0.000428) -> Train Acc: 91.06%, Test Acc: 87.27% | Train Loss: 0.2603
# [Epoch 166/300](LR: 0.000422) -> Train Acc: 89.55%, Test Acc: 88.18% | Train Loss: 0.3449
# [Epoch 167/300](LR: 0.000417) -> Train Acc: 88.94%, Test Acc: 85.00% | Train Loss: 0.3206
# [Epoch 168/300](LR: 0.000412) -> Train Acc: 90.76%, Test Acc: 86.82% | Train Loss: 0.2784
# [Epoch 169/300](LR: 0.000407) -> Train Acc: 91.97%, Test Acc: 85.91% | Train Loss: 0.2749
# [Epoch 170/300](LR: 0.000402) -> Train Acc: 90.15%, Test Acc: 87.73% | Train Loss: 0.3213
# [Epoch 171/300](LR: 0.000397) -> Train Acc: 90.76%, Test Acc: 85.45% | Train Loss: 0.3223
# [Epoch 172/300](LR: 0.000392) -> Train Acc: 88.48%, Test Acc: 85.91% | Train Loss: 0.3174
# [Epoch 173/300](LR: 0.000387) -> Train Acc: 91.52%, Test Acc: 84.55% | Train Loss: 0.2595
# [Epoch 174/300](LR: 0.000382) -> Train Acc: 90.76%, Test Acc: 87.73% | Train Loss: 0.2896
# [Epoch 175/300](LR: 0.000377) -> Train Acc: 92.27%, Test Acc: 87.27% | Train Loss: 0.2783
# [Epoch 176/300](LR: 0.000372) -> Train Acc: 90.45%, Test Acc: 85.00% | Train Loss: 0.2929
# [Epoch 177/300](LR: 0.000367) -> Train Acc: 89.09%, Test Acc: 86.36% | Train Loss: 0.3430
# [Epoch 178/300](LR: 0.000362) -> Train Acc: 91.67%, Test Acc: 85.00% | Train Loss: 0.2686
# [Epoch 179/300](LR: 0.000357) -> Train Acc: 90.15%, Test Acc: 86.36% | Train Loss: 0.3268
# [Epoch 180/300](LR: 0.000352) -> Train Acc: 91.06%, Test Acc: 88.64% | Train Loss: 0.3022
# [Epoch 181/300](LR: 0.000347) -> Train Acc: 91.06%, Test Acc: 85.45% | Train Loss: 0.2826
# [Epoch 182/300](LR: 0.000342) -> Train Acc: 90.00%, Test Acc: 87.73% | Train Loss: 0.2939
# [Epoch 183/300](LR: 0.000337) -> Train Acc: 91.97%, Test Acc: 85.45% | Train Loss: 0.2449
# [Epoch 184/300](LR: 0.000332) -> Train Acc: 92.42%, Test Acc: 86.36% | Train Loss: 0.2429
# [Epoch 185/300](LR: 0.000328) -> Train Acc: 91.36%, Test Acc: 85.45% | Train Loss: 0.2685
# [Epoch 186/300](LR: 0.000323) -> Train Acc: 92.88%, Test Acc: 86.36% | Train Loss: 0.2386
# [Epoch 187/300](LR: 0.000318) -> Train Acc: 92.12%, Test Acc: 88.64% | Train Loss: 0.2323
# [Epoch 188/300](LR: 0.000313) -> Train Acc: 91.52%, Test Acc: 89.55% | Train Loss: 0.2488
# [Epoch 189/300](LR: 0.000308) -> Train Acc: 93.33%, Test Acc: 85.45% | Train Loss: 0.2444
# [Epoch 190/300](LR: 0.000304) -> Train Acc: 92.58%, Test Acc: 86.82% | Train Loss: 0.2416
# [Epoch 191/300](LR: 0.000299) -> Train Acc: 91.36%, Test Acc: 86.82% | Train Loss: 0.2704
# [Epoch 192/300](LR: 0.000294) -> Train Acc: 90.91%, Test Acc: 86.82% | Train Loss: 0.2762
# [Epoch 193/300](LR: 0.000290) -> Train Acc: 91.97%, Test Acc: 85.91% | Train Loss: 0.2804
# [Epoch 194/300](LR: 0.000285) -> Train Acc: 94.24%, Test Acc: 87.27% | Train Loss: 0.1942
# [Epoch 195/300](LR: 0.000280) -> Train Acc: 92.58%, Test Acc: 85.91% | Train Loss: 0.2431
# [Epoch 196/300](LR: 0.000276) -> Train Acc: 92.88%, Test Acc: 89.09% | Train Loss: 0.2303
# [Epoch 197/300](LR: 0.000271) -> Train Acc: 91.82%, Test Acc: 87.73% | Train Loss: 0.2874
# [Epoch 198/300](LR: 0.000267) -> Train Acc: 91.67%, Test Acc: 86.82% | Train Loss: 0.2599
# [Epoch 199/300](LR: 0.000262) -> Train Acc: 92.27%, Test Acc: 87.73% | Train Loss: 0.2747
# [Epoch 200/300](LR: 0.000257) -> Train Acc: 92.12%, Test Acc: 88.64% | Train Loss: 0.2389
# [Epoch 201/300](LR: 0.000253) -> Train Acc: 91.97%, Test Acc: 87.27% | Train Loss: 0.2512
# [Epoch 202/300](LR: 0.000249) -> Train Acc: 93.33%, Test Acc: 87.27% | Train Loss: 0.2092
# [Epoch 203/300](LR: 0.000244) -> Train Acc: 93.64%, Test Acc: 87.73% | Train Loss: 0.2213
# [Epoch 204/300](LR: 0.000240) -> Train Acc: 90.76%, Test Acc: 87.73% | Train Loss: 0.2778
# [Epoch 205/300](LR: 0.000235) -> Train Acc: 93.03%, Test Acc: 86.36% | Train Loss: 0.2369
# [Epoch 206/300](LR: 0.000231) -> Train Acc: 93.03%, Test Acc: 86.82% | Train Loss: 0.2256
# [Epoch 207/300](LR: 0.000227) -> Train Acc: 91.82%, Test Acc: 86.36% | Train Loss: 0.2325
# [Epoch 208/300](LR: 0.000222) -> Train Acc: 92.42%, Test Acc: 87.27% | Train Loss: 0.2343
# [Epoch 209/300](LR: 0.000218) -> Train Acc: 91.06%, Test Acc: 87.27% | Train Loss: 0.2251
# [Epoch 210/300](LR: 0.000214) -> Train Acc: 92.73%, Test Acc: 87.27% | Train Loss: 0.2241
# [Epoch 211/300](LR: 0.000210) -> Train Acc: 93.33%, Test Acc: 86.82% | Train Loss: 0.2120
# [Epoch 212/300](LR: 0.000206) -> Train Acc: 93.48%, Test Acc: 86.36% | Train Loss: 0.1973
# [Epoch 213/300](LR: 0.000202) -> Train Acc: 93.33%, Test Acc: 87.73% | Train Loss: 0.2369
# [Epoch 214/300](LR: 0.000198) -> Train Acc: 94.09%, Test Acc: 86.36% | Train Loss: 0.2112
# [Epoch 215/300](LR: 0.000193) -> Train Acc: 94.70%, Test Acc: 86.82% | Train Loss: 0.1912
# [Epoch 216/300](LR: 0.000189) -> Train Acc: 95.30%, Test Acc: 86.82% | Train Loss: 0.1737
# [Epoch 217/300](LR: 0.000185) -> Train Acc: 92.27%, Test Acc: 86.36% | Train Loss: 0.2472
# [Epoch 218/300](LR: 0.000182) -> Train Acc: 93.03%, Test Acc: 87.73% | Train Loss: 0.2125
# [Epoch 219/300](LR: 0.000178) -> Train Acc: 94.70%, Test Acc: 87.73% | Train Loss: 0.1895
# [Epoch 220/300](LR: 0.000174) -> Train Acc: 94.24%, Test Acc: 87.73% | Train Loss: 0.1534
# [Epoch 221/300](LR: 0.000170) -> Train Acc: 93.79%, Test Acc: 88.18% | Train Loss: 0.2030
# [Epoch 222/300](LR: 0.000166) -> Train Acc: 93.33%, Test Acc: 87.73% | Train Loss: 0.2071
# [Epoch 223/300](LR: 0.000162) -> Train Acc: 94.85%, Test Acc: 87.27% | Train Loss: 0.2053
# [Epoch 224/300](LR: 0.000159) -> Train Acc: 94.09%, Test Acc: 86.82% | Train Loss: 0.1737
# [Epoch 225/300](LR: 0.000155) -> Train Acc: 93.03%, Test Acc: 87.27% | Train Loss: 0.2229
# [Epoch 226/300](LR: 0.000151) -> Train Acc: 94.09%, Test Acc: 86.82% | Train Loss: 0.1759
# [Epoch 227/300](LR: 0.000148) -> Train Acc: 93.79%, Test Acc: 86.36% | Train Loss: 0.2156
# [Epoch 228/300](LR: 0.000144) -> Train Acc: 94.24%, Test Acc: 88.64% | Train Loss: 0.1934
# [Epoch 229/300](LR: 0.000141) -> Train Acc: 94.55%, Test Acc: 88.18% | Train Loss: 0.1871
# [Epoch 230/300](LR: 0.000137) -> Train Acc: 95.15%, Test Acc: 87.73% | Train Loss: 0.1606
# [Epoch 231/300](LR: 0.000134) -> Train Acc: 95.30%, Test Acc: 88.18% | Train Loss: 0.1592
# [Epoch 232/300](LR: 0.000130) -> Train Acc: 93.64%, Test Acc: 89.09% | Train Loss: 0.1787
# [Epoch 233/300](LR: 0.000127) -> Train Acc: 94.70%, Test Acc: 87.73% | Train Loss: 0.1728
# [Epoch 234/300](LR: 0.000124) -> Train Acc: 93.48%, Test Acc: 88.18% | Train Loss: 0.2140
# [Epoch 235/300](LR: 0.000120) -> Train Acc: 94.55%, Test Acc: 88.18% | Train Loss: 0.1825
# [Epoch 236/300](LR: 0.000117) -> Train Acc: 95.15%, Test Acc: 88.18% | Train Loss: 0.1993
# [Epoch 237/300](LR: 0.000114) -> Train Acc: 94.24%, Test Acc: 88.64% | Train Loss: 0.1732
# [Epoch 238/300](LR: 0.000111) -> Train Acc: 93.33%, Test Acc: 88.18% | Train Loss: 0.2099
# [Epoch 239/300](LR: 0.000108) -> Train Acc: 94.55%, Test Acc: 89.55% | Train Loss: 0.1860
# [Epoch 240/300](LR: 0.000105) -> Train Acc: 96.06%, Test Acc: 87.73% | Train Loss: 0.1455
# [Epoch 241/300](LR: 0.000102) -> Train Acc: 95.91%, Test Acc: 88.18% | Train Loss: 0.1649
# [Epoch 242/300](LR: 0.000099) -> Train Acc: 94.70%, Test Acc: 89.09% | Train Loss: 0.1744
# [Epoch 243/300](LR: 0.000096) -> Train Acc: 93.18%, Test Acc: 87.27% | Train Loss: 0.2061
# [Epoch 244/300](LR: 0.000093) -> Train Acc: 93.94%, Test Acc: 87.73% | Train Loss: 0.1825
# [Epoch 245/300](LR: 0.000090) -> Train Acc: 95.45%, Test Acc: 86.82% | Train Loss: 0.1572
# [Epoch 246/300](LR: 0.000087) -> Train Acc: 93.03%, Test Acc: 88.18% | Train Loss: 0.2259
# [Epoch 247/300](LR: 0.000084) -> Train Acc: 95.45%, Test Acc: 88.18% | Train Loss: 0.1605
# [Epoch 248/300](LR: 0.000082) -> Train Acc: 95.15%, Test Acc: 88.18% | Train Loss: 0.1807
# [Epoch 249/300](LR: 0.000079) -> Train Acc: 93.48%, Test Acc: 88.18% | Train Loss: 0.1880
# [Epoch 250/300](LR: 0.000076) -> Train Acc: 95.61%, Test Acc: 86.82% | Train Loss: 0.1567
# [Epoch 251/300](LR: 0.000074) -> Train Acc: 96.36%, Test Acc: 86.82% | Train Loss: 0.1359
# [Epoch 252/300](LR: 0.000071) -> Train Acc: 93.94%, Test Acc: 87.73% | Train Loss: 0.1912
# [Epoch 253/300](LR: 0.000069) -> Train Acc: 95.45%, Test Acc: 86.36% | Train Loss: 0.1622
# [Epoch 254/300](LR: 0.000066) -> Train Acc: 94.85%, Test Acc: 88.18% | Train Loss: 0.1561
# [Epoch 255/300](LR: 0.000064) -> Train Acc: 95.30%, Test Acc: 86.82% | Train Loss: 0.1474
# [Epoch 256/300](LR: 0.000062) -> Train Acc: 94.39%, Test Acc: 87.27% | Train Loss: 0.1639
# [Epoch 257/300](LR: 0.000059) -> Train Acc: 95.45%, Test Acc: 86.82% | Train Loss: 0.1457
# [Epoch 258/300](LR: 0.000057) -> Train Acc: 95.45%, Test Acc: 88.18% | Train Loss: 0.1554
# [Epoch 259/300](LR: 0.000055) -> Train Acc: 94.70%, Test Acc: 86.82% | Train Loss: 0.2014
# [Epoch 260/300](LR: 0.000053) -> Train Acc: 93.64%, Test Acc: 87.73% | Train Loss: 0.1890
# [Epoch 261/300](LR: 0.000051) -> Train Acc: 93.03%, Test Acc: 87.73% | Train Loss: 0.2025
# [Epoch 262/300](LR: 0.000049) -> Train Acc: 95.91%, Test Acc: 87.27% | Train Loss: 0.1600
# [Epoch 263/300](LR: 0.000047) -> Train Acc: 93.03%, Test Acc: 89.09% | Train Loss: 0.2191
# [Epoch 264/300](LR: 0.000045) -> Train Acc: 96.06%, Test Acc: 88.18% | Train Loss: 0.1549
# [Epoch 265/300](LR: 0.000043) -> Train Acc: 95.91%, Test Acc: 88.18% | Train Loss: 0.1567
# [Epoch 266/300](LR: 0.000041) -> Train Acc: 95.45%, Test Acc: 88.18% | Train Loss: 0.1529
# [Epoch 267/300](LR: 0.000039) -> Train Acc: 95.00%, Test Acc: 88.18% | Train Loss: 0.1670
# [Epoch 268/300](LR: 0.000038) -> Train Acc: 94.24%, Test Acc: 87.73% | Train Loss: 0.1852
# [Epoch 269/300](LR: 0.000036) -> Train Acc: 93.48%, Test Acc: 87.73% | Train Loss: 0.1905
# [Epoch 270/300](LR: 0.000034) -> Train Acc: 95.45%, Test Acc: 88.18% | Train Loss: 0.1657
# [Epoch 271/300](LR: 0.000033) -> Train Acc: 95.00%, Test Acc: 88.18% | Train Loss: 0.1242
# [Epoch 272/300](LR: 0.000031) -> Train Acc: 95.76%, Test Acc: 88.18% | Train Loss: 0.1444
# [Epoch 273/300](LR: 0.000030) -> Train Acc: 95.30%, Test Acc: 89.09% | Train Loss: 0.1534
# [Epoch 274/300](LR: 0.000028) -> Train Acc: 94.39%, Test Acc: 87.73% | Train Loss: 0.1831
# [Epoch 275/300](LR: 0.000027) -> Train Acc: 95.76%, Test Acc: 89.09% | Train Loss: 0.1440
# [Epoch 276/300](LR: 0.000026) -> Train Acc: 94.70%, Test Acc: 88.18% | Train Loss: 0.1789
# [Epoch 277/300](LR: 0.000024) -> Train Acc: 95.00%, Test Acc: 87.73% | Train Loss: 0.1549
# [Epoch 278/300](LR: 0.000023) -> Train Acc: 94.70%, Test Acc: 89.55% | Train Loss: 0.1721
# [Epoch 279/300](LR: 0.000022) -> Train Acc: 96.21%, Test Acc: 88.18% | Train Loss: 0.1477
# [Epoch 280/300](LR: 0.000021) -> Train Acc: 93.48%, Test Acc: 88.64% | Train Loss: 0.1999
# [Epoch 281/300](LR: 0.000020) -> Train Acc: 95.30%, Test Acc: 88.18% | Train Loss: 0.1460
# [Epoch 282/300](LR: 0.000019) -> Train Acc: 95.15%, Test Acc: 89.09% | Train Loss: 0.1590
# [Epoch 283/300](LR: 0.000018) -> Train Acc: 95.91%, Test Acc: 88.64% | Train Loss: 0.1333
# [Epoch 284/300](LR: 0.000017) -> Train Acc: 95.30%, Test Acc: 88.64% | Train Loss: 0.1462
# [Epoch 285/300](LR: 0.000016) -> Train Acc: 95.15%, Test Acc: 89.55% | Train Loss: 0.1719
# [Epoch 286/300](LR: 0.000015) -> Train Acc: 96.06%, Test Acc: 90.45% | Train Loss: 0.1379
# [Epoch 287/300](LR: 0.000015) -> Train Acc: 96.36%, Test Acc: 89.09% | Train Loss: 0.1257
# [Epoch 288/300](LR: 0.000014) -> Train Acc: 92.88%, Test Acc: 89.55% | Train Loss: 0.2083
# [Epoch 289/300](LR: 0.000013) -> Train Acc: 94.09%, Test Acc: 90.00% | Train Loss: 0.1648
# [Epoch 290/300](LR: 0.000013) -> Train Acc: 95.61%, Test Acc: 89.09% | Train Loss: 0.1418
# [Epoch 291/300](LR: 0.000012) -> Train Acc: 93.79%, Test Acc: 89.55% | Train Loss: 0.1979
# [Epoch 292/300](LR: 0.000012) -> Train Acc: 95.61%, Test Acc: 89.55% | Train Loss: 0.1740
# [Epoch 293/300](LR: 0.000011) -> Train Acc: 95.30%, Test Acc: 89.55% | Train Loss: 0.1424
# [Epoch 294/300](LR: 0.000011) -> Train Acc: 95.30%, Test Acc: 88.64% | Train Loss: 0.1488
# [Epoch 295/300](LR: 0.000011) -> Train Acc: 95.76%, Test Acc: 89.09% | Train Loss: 0.1434
# [Epoch 296/300](LR: 0.000010) -> Train Acc: 94.39%, Test Acc: 89.09% | Train Loss: 0.1703
# [Epoch 297/300](LR: 0.000010) -> Train Acc: 94.24%, Test Acc: 89.09% | Train Loss: 0.2180
# [Epoch 298/300](LR: 0.000010) -> Train Acc: 97.12%, Test Acc: 89.09% | Train Loss: 0.1188
# [Epoch 299/300](LR: 0.000010) -> Train Acc: 95.30%, Test Acc: 88.64% | Train Loss: 0.1602
# [Epoch 300/300](LR: 0.000010) -> Train Acc: 94.39%, Test Acc: 89.09% | Train Loss: 0.1623

# %% [markdown]
# ##### ReduceLROnPlateau

# %%
flexible_cnn_2 = get_flexible_cnn(num_classes=110).to(device)
optimizer = optim.Adam(flexible_cnn_2.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in flexible_cnn_2.parameters())
print(f"总参数量: {total_params:,}")
history2 = train(flexible_cnn_2, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=200)
# Out:
# 总参数量: 2,252,430
# 开始训练，设备: cuda
# [Epoch 1/200](LR: 0.001000) -> Train Acc: 0.45%, Test Acc: 0.00% | Train Loss: 4.8548
# [Epoch 2/200](LR: 0.001000) -> Train Acc: 1.06%, Test Acc: 1.82% | Train Loss: 4.6415
# [Epoch 3/200](LR: 0.001000) -> Train Acc: 2.42%, Test Acc: 1.82% | Train Loss: 4.5171
# [Epoch 4/200](LR: 0.001000) -> Train Acc: 2.42%, Test Acc: 4.55% | Train Loss: 4.3898
# [Epoch 5/200](LR: 0.001000) -> Train Acc: 3.79%, Test Acc: 4.09% | Train Loss: 4.2009
# [Epoch 6/200](LR: 0.001000) -> Train Acc: 4.85%, Test Acc: 7.27% | Train Loss: 4.0838
# [Epoch 7/200](LR: 0.001000) -> Train Acc: 4.39%, Test Acc: 8.18% | Train Loss: 3.9747
# [Epoch 8/200](LR: 0.001000) -> Train Acc: 6.67%, Test Acc: 5.45% | Train Loss: 3.8453
# [Epoch 9/200](LR: 0.001000) -> Train Acc: 7.88%, Test Acc: 8.64% | Train Loss: 3.7073
# [Epoch 10/200](LR: 0.001000) -> Train Acc: 9.09%, Test Acc: 6.36% | Train Loss: 3.6216
# [Epoch 11/200](LR: 0.001000) -> Train Acc: 10.61%, Test Acc: 16.36% | Train Loss: 3.5120
# [Epoch 12/200](LR: 0.001000) -> Train Acc: 12.42%, Test Acc: 9.09% | Train Loss: 3.3533
# [Epoch 13/200](LR: 0.001000) -> Train Acc: 14.55%, Test Acc: 20.45% | Train Loss: 3.3108
# [Epoch 14/200](LR: 0.001000) -> Train Acc: 13.94%, Test Acc: 24.09% | Train Loss: 3.1792
# [Epoch 15/200](LR: 0.001000) -> Train Acc: 15.30%, Test Acc: 18.64% | Train Loss: 3.0424
# [Epoch 16/200](LR: 0.001000) -> Train Acc: 17.58%, Test Acc: 25.45% | Train Loss: 2.9311
# [Epoch 17/200](LR: 0.001000) -> Train Acc: 17.42%, Test Acc: 28.18% | Train Loss: 2.9229
# [Epoch 18/200](LR: 0.001000) -> Train Acc: 19.85%, Test Acc: 18.64% | Train Loss: 2.7591
# [Epoch 19/200](LR: 0.001000) -> Train Acc: 23.94%, Test Acc: 31.82% | Train Loss: 2.6845
# [Epoch 20/200](LR: 0.001000) -> Train Acc: 22.73%, Test Acc: 32.27% | Train Loss: 2.6821
# [Epoch 21/200](LR: 0.001000) -> Train Acc: 26.67%, Test Acc: 35.91% | Train Loss: 2.4916
# [Epoch 22/200](LR: 0.001000) -> Train Acc: 30.00%, Test Acc: 36.82% | Train Loss: 2.4749
# [Epoch 23/200](LR: 0.001000) -> Train Acc: 29.39%, Test Acc: 42.27% | Train Loss: 2.4946
# [Epoch 24/200](LR: 0.001000) -> Train Acc: 29.39%, Test Acc: 43.64% | Train Loss: 2.3710
# [Epoch 25/200](LR: 0.001000) -> Train Acc: 30.45%, Test Acc: 45.91% | Train Loss: 2.3069
# [Epoch 26/200](LR: 0.001000) -> Train Acc: 30.30%, Test Acc: 41.36% | Train Loss: 2.3982
# [Epoch 27/200](LR: 0.001000) -> Train Acc: 36.97%, Test Acc: 34.55% | Train Loss: 2.1406
# [Epoch 28/200](LR: 0.001000) -> Train Acc: 35.30%, Test Acc: 55.45% | Train Loss: 2.1584
# [Epoch 29/200](LR: 0.001000) -> Train Acc: 39.09%, Test Acc: 54.09% | Train Loss: 1.9929
# [Epoch 30/200](LR: 0.001000) -> Train Acc: 41.06%, Test Acc: 58.18% | Train Loss: 1.9924
# [Epoch 31/200](LR: 0.001000) -> Train Acc: 38.94%, Test Acc: 51.36% | Train Loss: 1.9471
# [Epoch 32/200](LR: 0.001000) -> Train Acc: 42.73%, Test Acc: 51.36% | Train Loss: 1.9291
# [Epoch 33/200](LR: 0.001000) -> Train Acc: 44.24%, Test Acc: 26.82% | Train Loss: 1.8281
# [Epoch 34/200](LR: 0.001000) -> Train Acc: 43.18%, Test Acc: 54.55% | Train Loss: 1.8341
# [Epoch 35/200](LR: 0.001000) -> Train Acc: 42.42%, Test Acc: 41.82% | Train Loss: 1.8609
# [Epoch 36/200](LR: 0.000500) -> Train Acc: 44.09%, Test Acc: 56.36% | Train Loss: 1.8460
# [Epoch 37/200](LR: 0.000500) -> Train Acc: 50.61%, Test Acc: 64.09% | Train Loss: 1.6161
# [Epoch 38/200](LR: 0.000500) -> Train Acc: 56.52%, Test Acc: 66.82% | Train Loss: 1.4152
# [Epoch 39/200](LR: 0.000500) -> Train Acc: 56.97%, Test Acc: 69.09% | Train Loss: 1.4102
# [Epoch 40/200](LR: 0.000500) -> Train Acc: 55.45%, Test Acc: 66.82% | Train Loss: 1.4038
# [Epoch 41/200](LR: 0.000500) -> Train Acc: 56.21%, Test Acc: 65.91% | Train Loss: 1.3898
# [Epoch 42/200](LR: 0.000500) -> Train Acc: 55.61%, Test Acc: 66.36% | Train Loss: 1.3517
# [Epoch 43/200](LR: 0.000500) -> Train Acc: 55.45%, Test Acc: 56.36% | Train Loss: 1.4400
# [Epoch 44/200](LR: 0.000500) -> Train Acc: 54.09%, Test Acc: 72.27% | Train Loss: 1.4985
# [Epoch 45/200](LR: 0.000500) -> Train Acc: 53.48%, Test Acc: 69.09% | Train Loss: 1.3856
# [Epoch 46/200](LR: 0.000500) -> Train Acc: 59.39%, Test Acc: 71.36% | Train Loss: 1.2735
# [Epoch 47/200](LR: 0.000500) -> Train Acc: 58.64%, Test Acc: 66.36% | Train Loss: 1.2890
# [Epoch 48/200](LR: 0.000500) -> Train Acc: 60.30%, Test Acc: 74.55% | Train Loss: 1.2433
# [Epoch 49/200](LR: 0.000500) -> Train Acc: 63.33%, Test Acc: 72.27% | Train Loss: 1.1741
# [Epoch 50/200](LR: 0.000500) -> Train Acc: 62.27%, Test Acc: 68.18% | Train Loss: 1.2344
# [Epoch 51/200](LR: 0.000500) -> Train Acc: 62.88%, Test Acc: 75.45% | Train Loss: 1.1899
# [Epoch 52/200](LR: 0.000500) -> Train Acc: 64.24%, Test Acc: 71.82% | Train Loss: 1.1599
# [Epoch 53/200](LR: 0.000500) -> Train Acc: 62.42%, Test Acc: 68.64% | Train Loss: 1.1811
# [Epoch 54/200](LR: 0.000500) -> Train Acc: 63.48%, Test Acc: 70.91% | Train Loss: 1.1197
# [Epoch 55/200](LR: 0.000500) -> Train Acc: 61.06%, Test Acc: 70.91% | Train Loss: 1.1711
# [Epoch 56/200](LR: 0.000500) -> Train Acc: 70.30%, Test Acc: 72.27% | Train Loss: 1.0022
# [Epoch 57/200](LR: 0.000250) -> Train Acc: 66.06%, Test Acc: 74.09% | Train Loss: 1.0575
# [Epoch 58/200](LR: 0.000250) -> Train Acc: 68.18%, Test Acc: 75.45% | Train Loss: 0.9986
# [Epoch 59/200](LR: 0.000250) -> Train Acc: 72.12%, Test Acc: 76.36% | Train Loss: 0.9459
# [Epoch 60/200](LR: 0.000250) -> Train Acc: 69.24%, Test Acc: 76.82% | Train Loss: 0.9685
# [Epoch 61/200](LR: 0.000250) -> Train Acc: 73.79%, Test Acc: 79.09% | Train Loss: 0.8474
# [Epoch 62/200](LR: 0.000250) -> Train Acc: 71.67%, Test Acc: 79.55% | Train Loss: 0.8527
# [Epoch 63/200](LR: 0.000250) -> Train Acc: 69.24%, Test Acc: 78.64% | Train Loss: 0.9756
# [Epoch 64/200](LR: 0.000250) -> Train Acc: 72.73%, Test Acc: 73.64% | Train Loss: 0.8791
# [Epoch 65/200](LR: 0.000250) -> Train Acc: 71.52%, Test Acc: 77.73% | Train Loss: 0.9061
# [Epoch 66/200](LR: 0.000250) -> Train Acc: 68.33%, Test Acc: 78.18% | Train Loss: 0.9358
# [Epoch 67/200](LR: 0.000250) -> Train Acc: 70.45%, Test Acc: 81.36% | Train Loss: 0.9135
# [Epoch 68/200](LR: 0.000250) -> Train Acc: 72.27%, Test Acc: 79.09% | Train Loss: 0.8915
# [Epoch 69/200](LR: 0.000250) -> Train Acc: 75.30%, Test Acc: 77.73% | Train Loss: 0.8249
# [Epoch 70/200](LR: 0.000250) -> Train Acc: 71.97%, Test Acc: 74.09% | Train Loss: 0.8887
# [Epoch 71/200](LR: 0.000250) -> Train Acc: 71.52%, Test Acc: 79.55% | Train Loss: 0.8646
# [Epoch 72/200](LR: 0.000250) -> Train Acc: 74.09%, Test Acc: 81.82% | Train Loss: 0.8052
# [Epoch 73/200](LR: 0.000250) -> Train Acc: 76.52%, Test Acc: 80.91% | Train Loss: 0.7746
# [Epoch 74/200](LR: 0.000250) -> Train Acc: 74.55%, Test Acc: 80.91% | Train Loss: 0.8332
# [Epoch 75/200](LR: 0.000250) -> Train Acc: 75.91%, Test Acc: 80.91% | Train Loss: 0.8139
# [Epoch 76/200](LR: 0.000250) -> Train Acc: 71.52%, Test Acc: 80.45% | Train Loss: 0.8447
# [Epoch 77/200](LR: 0.000250) -> Train Acc: 71.67%, Test Acc: 79.09% | Train Loss: 0.8922
# [Epoch 78/200](LR: 0.000125) -> Train Acc: 75.91%, Test Acc: 81.36% | Train Loss: 0.7680
# [Epoch 79/200](LR: 0.000125) -> Train Acc: 74.85%, Test Acc: 80.91% | Train Loss: 0.7582
# [Epoch 80/200](LR: 0.000125) -> Train Acc: 79.55%, Test Acc: 84.09% | Train Loss: 0.7007
# [Epoch 81/200](LR: 0.000125) -> Train Acc: 76.67%, Test Acc: 78.64% | Train Loss: 0.7473
# [Epoch 82/200](LR: 0.000125) -> Train Acc: 78.48%, Test Acc: 80.45% | Train Loss: 0.6582
# [Epoch 83/200](LR: 0.000125) -> Train Acc: 75.15%, Test Acc: 80.45% | Train Loss: 0.7682
# [Epoch 84/200](LR: 0.000125) -> Train Acc: 78.48%, Test Acc: 81.82% | Train Loss: 0.6766
# [Epoch 85/200](LR: 0.000125) -> Train Acc: 77.73%, Test Acc: 83.18% | Train Loss: 0.7003
# [Epoch 86/200](LR: 0.000063) -> Train Acc: 78.33%, Test Acc: 82.27% | Train Loss: 0.7393
# [Epoch 87/200](LR: 0.000063) -> Train Acc: 78.64%, Test Acc: 82.73% | Train Loss: 0.6698
# [Epoch 88/200](LR: 0.000063) -> Train Acc: 81.36%, Test Acc: 83.18% | Train Loss: 0.6227
# [Epoch 89/200](LR: 0.000063) -> Train Acc: 78.03%, Test Acc: 83.64% | Train Loss: 0.7172
# [Epoch 90/200](LR: 0.000063) -> Train Acc: 82.42%, Test Acc: 83.18% | Train Loss: 0.5730
# [Epoch 91/200](LR: 0.000063) -> Train Acc: 78.94%, Test Acc: 83.18% | Train Loss: 0.6864
# [Epoch 92/200](LR: 0.000031) -> Train Acc: 80.91%, Test Acc: 83.64% | Train Loss: 0.6300
# [Epoch 93/200](LR: 0.000031) -> Train Acc: 80.30%, Test Acc: 83.64% | Train Loss: 0.6403
# [Epoch 94/200](LR: 0.000031) -> Train Acc: 80.30%, Test Acc: 84.09% | Train Loss: 0.6329
# [Epoch 95/200](LR: 0.000031) -> Train Acc: 78.79%, Test Acc: 83.64% | Train Loss: 0.6615
# [Epoch 96/200](LR: 0.000031) -> Train Acc: 81.06%, Test Acc: 84.09% | Train Loss: 0.6182
# [Epoch 97/200](LR: 0.000031) -> Train Acc: 78.18%, Test Acc: 84.55% | Train Loss: 0.6826
# [Epoch 98/200](LR: 0.000031) -> Train Acc: 82.73%, Test Acc: 83.64% | Train Loss: 0.6125
# [Epoch 99/200](LR: 0.000031) -> Train Acc: 82.42%, Test Acc: 84.09% | Train Loss: 0.5720
# [Epoch 100/200](LR: 0.000031) -> Train Acc: 78.94%, Test Acc: 83.64% | Train Loss: 0.6538
# [Epoch 101/200](LR: 0.000031) -> Train Acc: 80.76%, Test Acc: 85.00% | Train Loss: 0.6400
# [Epoch 102/200](LR: 0.000031) -> Train Acc: 78.33%, Test Acc: 83.64% | Train Loss: 0.7082
# [Epoch 103/200](LR: 0.000031) -> Train Acc: 80.61%, Test Acc: 84.55% | Train Loss: 0.5821
# [Epoch 104/200](LR: 0.000031) -> Train Acc: 81.36%, Test Acc: 84.55% | Train Loss: 0.6017
# [Epoch 105/200](LR: 0.000031) -> Train Acc: 78.94%, Test Acc: 83.18% | Train Loss: 0.6314
# [Epoch 106/200](LR: 0.000031) -> Train Acc: 81.06%, Test Acc: 82.73% | Train Loss: 0.5937
# [Epoch 107/200](LR: 0.000016) -> Train Acc: 81.21%, Test Acc: 83.18% | Train Loss: 0.6037
# [Epoch 108/200](LR: 0.000016) -> Train Acc: 81.36%, Test Acc: 83.18% | Train Loss: 0.6106
# [Epoch 109/200](LR: 0.000016) -> Train Acc: 80.00%, Test Acc: 84.55% | Train Loss: 0.6191
# [Epoch 110/200](LR: 0.000016) -> Train Acc: 79.39%, Test Acc: 84.09% | Train Loss: 0.7081
# [Epoch 111/200](LR: 0.000016) -> Train Acc: 79.39%, Test Acc: 84.09% | Train Loss: 0.6417
# [Epoch 112/200](LR: 0.000016) -> Train Acc: 78.03%, Test Acc: 84.55% | Train Loss: 0.6611
# [Epoch 113/200](LR: 0.000008) -> Train Acc: 80.91%, Test Acc: 82.73% | Train Loss: 0.6066
# [Epoch 114/200](LR: 0.000008) -> Train Acc: 82.58%, Test Acc: 84.09% | Train Loss: 0.5893
# [Epoch 115/200](LR: 0.000008) -> Train Acc: 79.09%, Test Acc: 83.64% | Train Loss: 0.6902
# [Epoch 116/200](LR: 0.000008) -> Train Acc: 82.12%, Test Acc: 83.64% | Train Loss: 0.5708
# [Epoch 117/200](LR: 0.000008) -> Train Acc: 80.91%, Test Acc: 84.55% | Train Loss: 0.6323
# [Epoch 118/200](LR: 0.000008) -> Train Acc: 81.97%, Test Acc: 84.09% | Train Loss: 0.5811
# [Epoch 119/200](LR: 0.000004) -> Train Acc: 82.27%, Test Acc: 84.09% | Train Loss: 0.5613
# [Epoch 120/200](LR: 0.000004) -> Train Acc: 81.82%, Test Acc: 84.55% | Train Loss: 0.5928
# [Epoch 121/200](LR: 0.000004) -> Train Acc: 80.45%, Test Acc: 84.55% | Train Loss: 0.5787
# [Epoch 122/200](LR: 0.000004) -> Train Acc: 81.36%, Test Acc: 83.18% | Train Loss: 0.6011
# [Epoch 123/200](LR: 0.000004) -> Train Acc: 78.48%, Test Acc: 84.09% | Train Loss: 0.6532
# [Epoch 124/200](LR: 0.000004) -> Train Acc: 81.82%, Test Acc: 84.09% | Train Loss: 0.5931
# [Epoch 125/200](LR: 0.000002) -> Train Acc: 79.09%, Test Acc: 82.73% | Train Loss: 0.7245
# [Epoch 126/200](LR: 0.000002) -> Train Acc: 80.61%, Test Acc: 84.09% | Train Loss: 0.6018
# [Epoch 127/200](LR: 0.000002) -> Train Acc: 82.42%, Test Acc: 85.00% | Train Loss: 0.5689
# [Epoch 128/200](LR: 0.000002) -> Train Acc: 81.82%, Test Acc: 83.64% | Train Loss: 0.6053
# [Epoch 129/200](LR: 0.000002) -> Train Acc: 81.06%, Test Acc: 83.18% | Train Loss: 0.5898
# [Epoch 130/200](LR: 0.000002) -> Train Acc: 80.61%, Test Acc: 84.09% | Train Loss: 0.5916
# [Epoch 131/200](LR: 0.000001) -> Train Acc: 78.79%, Test Acc: 84.55% | Train Loss: 0.6712
# [Epoch 132/200](LR: 0.000001) -> Train Acc: 79.85%, Test Acc: 84.55% | Train Loss: 0.6309
# [Epoch 133/200](LR: 0.000001) -> Train Acc: 82.58%, Test Acc: 84.09% | Train Loss: 0.6086
# [Epoch 134/200](LR: 0.000001) -> Train Acc: 82.12%, Test Acc: 85.00% | Train Loss: 0.5817
# [Epoch 135/200](LR: 0.000001) -> Train Acc: 80.30%, Test Acc: 84.09% | Train Loss: 0.6159
# [Epoch 136/200](LR: 0.000001) -> Train Acc: 80.76%, Test Acc: 84.55% | Train Loss: 0.6335
# [Epoch 137/200](LR: 0.000000) -> Train Acc: 83.48%, Test Acc: 85.00% | Train Loss: 0.5398
# [Epoch 138/200](LR: 0.000000) -> Train Acc: 80.00%, Test Acc: 84.09% | Train Loss: 0.6540
# [Epoch 139/200](LR: 0.000000) -> Train Acc: 79.39%, Test Acc: 84.09% | Train Loss: 0.6250
# [Epoch 140/200](LR: 0.000000) -> Train Acc: 80.61%, Test Acc: 84.55% | Train Loss: 0.6106
# [Epoch 141/200](LR: 0.000000) -> Train Acc: 82.12%, Test Acc: 84.09% | Train Loss: 0.5951
# [Epoch 142/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 83.64% | Train Loss: 0.5697
# [Epoch 143/200](LR: 0.000000) -> Train Acc: 81.67%, Test Acc: 83.18% | Train Loss: 0.6387
# [Epoch 144/200](LR: 0.000000) -> Train Acc: 83.48%, Test Acc: 83.64% | Train Loss: 0.5759
# [Epoch 145/200](LR: 0.000000) -> Train Acc: 82.58%, Test Acc: 83.64% | Train Loss: 0.5710
# [Epoch 146/200](LR: 0.000000) -> Train Acc: 81.52%, Test Acc: 85.00% | Train Loss: 0.6106
# [Epoch 147/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 83.64% | Train Loss: 0.5837
# [Epoch 148/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 83.18% | Train Loss: 0.6285
# [Epoch 149/200](LR: 0.000000) -> Train Acc: 79.85%, Test Acc: 83.18% | Train Loss: 0.6518
# [Epoch 150/200](LR: 0.000000) -> Train Acc: 80.15%, Test Acc: 82.73% | Train Loss: 0.6145
# [Epoch 151/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 84.09% | Train Loss: 0.5784
# [Epoch 152/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 85.00% | Train Loss: 0.6237
# [Epoch 153/200](LR: 0.000000) -> Train Acc: 81.52%, Test Acc: 83.18% | Train Loss: 0.6343
# [Epoch 154/200](LR: 0.000000) -> Train Acc: 77.58%, Test Acc: 84.55% | Train Loss: 0.6859
# [Epoch 155/200](LR: 0.000000) -> Train Acc: 83.79%, Test Acc: 84.09% | Train Loss: 0.5657
# [Epoch 156/200](LR: 0.000000) -> Train Acc: 80.30%, Test Acc: 83.64% | Train Loss: 0.6737
# [Epoch 157/200](LR: 0.000000) -> Train Acc: 81.52%, Test Acc: 84.09% | Train Loss: 0.6420
# [Epoch 158/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 84.55% | Train Loss: 0.6012
# [Epoch 159/200](LR: 0.000000) -> Train Acc: 82.58%, Test Acc: 84.09% | Train Loss: 0.6013
# [Epoch 160/200](LR: 0.000000) -> Train Acc: 80.00%, Test Acc: 84.09% | Train Loss: 0.6238
# [Epoch 161/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 84.55% | Train Loss: 0.6153
# [Epoch 162/200](LR: 0.000000) -> Train Acc: 80.91%, Test Acc: 84.55% | Train Loss: 0.6731
# [Epoch 163/200](LR: 0.000000) -> Train Acc: 79.09%, Test Acc: 84.55% | Train Loss: 0.6537
# [Epoch 164/200](LR: 0.000000) -> Train Acc: 80.15%, Test Acc: 84.09% | Train Loss: 0.6518
# [Epoch 165/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 84.55% | Train Loss: 0.5917
# [Epoch 166/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 83.64% | Train Loss: 0.6101
# [Epoch 167/200](LR: 0.000000) -> Train Acc: 82.58%, Test Acc: 84.55% | Train Loss: 0.5995
# [Epoch 168/200](LR: 0.000000) -> Train Acc: 82.73%, Test Acc: 85.00% | Train Loss: 0.6106
# [Epoch 169/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 84.55% | Train Loss: 0.5790
# [Epoch 170/200](LR: 0.000000) -> Train Acc: 79.85%, Test Acc: 83.64% | Train Loss: 0.6604
# [Epoch 171/200](LR: 0.000000) -> Train Acc: 81.06%, Test Acc: 83.64% | Train Loss: 0.5877
# [Epoch 172/200](LR: 0.000000) -> Train Acc: 82.42%, Test Acc: 83.64% | Train Loss: 0.5750
# [Epoch 173/200](LR: 0.000000) -> Train Acc: 80.91%, Test Acc: 84.09% | Train Loss: 0.6363
# [Epoch 174/200](LR: 0.000000) -> Train Acc: 79.85%, Test Acc: 84.55% | Train Loss: 0.6240
# [Epoch 175/200](LR: 0.000000) -> Train Acc: 80.45%, Test Acc: 84.09% | Train Loss: 0.5981
# [Epoch 176/200](LR: 0.000000) -> Train Acc: 79.70%, Test Acc: 85.00% | Train Loss: 0.6596
# [Epoch 177/200](LR: 0.000000) -> Train Acc: 83.03%, Test Acc: 83.64% | Train Loss: 0.5700
# [Epoch 178/200](LR: 0.000000) -> Train Acc: 80.45%, Test Acc: 83.64% | Train Loss: 0.6128
# [Epoch 179/200](LR: 0.000000) -> Train Acc: 80.45%, Test Acc: 83.64% | Train Loss: 0.6284
# [Epoch 180/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 83.18% | Train Loss: 0.5868
# [Epoch 181/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 84.09% | Train Loss: 0.6541
# [Epoch 182/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 84.09% | Train Loss: 0.5710
# [Epoch 183/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 83.64% | Train Loss: 0.6277
# [Epoch 184/200](LR: 0.000000) -> Train Acc: 79.55%, Test Acc: 83.64% | Train Loss: 0.6293
# [Epoch 185/200](LR: 0.000000) -> Train Acc: 81.82%, Test Acc: 84.09% | Train Loss: 0.5819
# [Epoch 186/200](LR: 0.000000) -> Train Acc: 77.27%, Test Acc: 85.00% | Train Loss: 0.6617
# [Epoch 187/200](LR: 0.000000) -> Train Acc: 81.21%, Test Acc: 84.55% | Train Loss: 0.5984
# [Epoch 188/200](LR: 0.000000) -> Train Acc: 79.85%, Test Acc: 83.64% | Train Loss: 0.6588
# [Epoch 189/200](LR: 0.000000) -> Train Acc: 80.91%, Test Acc: 84.09% | Train Loss: 0.6218
# [Epoch 190/200](LR: 0.000000) -> Train Acc: 80.76%, Test Acc: 84.09% | Train Loss: 0.6391
# [Epoch 191/200](LR: 0.000000) -> Train Acc: 82.27%, Test Acc: 82.73% | Train Loss: 0.6105
# [Epoch 192/200](LR: 0.000000) -> Train Acc: 83.18%, Test Acc: 83.64% | Train Loss: 0.5891
# [Epoch 193/200](LR: 0.000000) -> Train Acc: 79.55%, Test Acc: 84.09% | Train Loss: 0.6177
# [Epoch 194/200](LR: 0.000000) -> Train Acc: 81.97%, Test Acc: 84.55% | Train Loss: 0.6241
# [Epoch 195/200](LR: 0.000000) -> Train Acc: 81.06%, Test Acc: 84.09% | Train Loss: 0.6435
# [Epoch 196/200](LR: 0.000000) -> Train Acc: 81.36%, Test Acc: 83.64% | Train Loss: 0.6190
# [Epoch 197/200](LR: 0.000000) -> Train Acc: 84.24%, Test Acc: 82.27% | Train Loss: 0.5342
# [Epoch 198/200](LR: 0.000000) -> Train Acc: 82.58%, Test Acc: 83.18% | Train Loss: 0.6232
# [Epoch 199/200](LR: 0.000000) -> Train Acc: 82.12%, Test Acc: 85.00% | Train Loss: 0.6233
# [Epoch 200/200](LR: 0.000000) -> Train Acc: 80.15%, Test Acc: 83.18% | Train Loss: 0.6187
