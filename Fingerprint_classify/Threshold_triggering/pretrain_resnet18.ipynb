# %% [markdown]
# # Pretrained ResNet18 - 阈值起振

# %% [markdown]
# 1. 采用**分层采样**：“每个手指固定 6 张训练、2 张测试”
# 能确保模型在训练时见过每一个手指，在测试时也能评估每一个手指。
# 2. 训练集：测试集 = 6:2，保持了合理的训练数据量，同时保证了测试的代表性。
# 3. **使用LR=0.001并进行学习率衰退**

# %% [markdown]
# **Result: %的测试准确率**

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
import matplotlib.pyplot as plt
from PIL import Image

from torch.utils.data import Subset
from collections import defaultdict
import random

# %%
DATA_DIR = '../../FVC2002/Db1'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1. 读取指纹数据

# %%
class FVC2002Dataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        # 过滤出所有的 .tif 文件
        self.image_files = [f for f in os.listdir(root_dir) if f.endswith('.tif')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.root_dir, img_name)
        
        # 加载图像并转为灰度图（指纹图通常是单通道）
        image = Image.open(img_path).convert('L')
        
        # 解析标签：例如 "10_3.tif" -> 标签为 10
        # 注意：类别索引通常从 0 开始，所以我们将 ID 减 1
        label = int(img_name.split('_')[0]) - 1
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# %%
# 临时加载数据集（仅 ToTensor）
dataset = FVC2002Dataset(root_dir=DATA_DIR,
                        transform=transforms.Compose([
                        transforms.Grayscale(),
                        transforms.ToTensor()
                               ]))
loader = DataLoader(dataset, batch_size=100, shuffle=False)

def calculate_mean_std(dataset):
    """
    Calculates the mean and standard deviation of a PyTorch dataset.

    Args:
        dataset (torch.utils.data.Dataset): The dataset for which to
                                            calculate the stats. It should
                                            return image tensors.

    Returns:
        (torch.Tensor, torch.Tensor): A tuple containing the mean and
                                      standard deviation tensors, each of
                                      shape (C,).
    """
    # Create a DataLoader to iterate through the dataset in batches for efficiency.
    # shuffle=False because the order of images doesn't matter for this calculation.
    loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=0)

    # Initialize tensors to store the sum of pixel values for each (RGB) channel.
    channel_sum = torch.zeros(1)
    # Initialize tensors to store the sum of squared pixel values for each channel.
    channel_sum_sq = torch.zeros(1)
    # Initialize a counter for the total number of pixels.
    num_pixels = 0

    # Wrap the loader with tqdm to create a progress bar for monitoring.
    for images, _ in tqdm(loader, desc="Calculating Dataset Stats"):
        # Add the total number of pixels in this batch to the running total.
        num_pixels += images.size(0) * images.size(2) * images.size(3)
        
        # Sum the pixel values across the batch, height, and width dimensions,
        # leaving only the channel dimension. Add this to the running total.
        channel_sum += images.sum(dim=[0, 2, 3])
        
        # Square each pixel value, then sum them up similarly to the step above.
        channel_sum_sq += (images ** 2).sum(dim=[0, 2, 3])

    # Calculate the mean for each channel.
    mean = channel_sum / num_pixels
    # Calculate the standard deviation using the formula: sqrt(E[X^2] - E[X]^2)
    std = (channel_sum_sq / num_pixels - mean ** 2) ** 0.5

    # Return the calculated mean and standard deviation.
    return mean, std

mean, std = calculate_mean_std(dataset)
print(f"Mean: {mean}, Std: {std}")
# Out:
# Mean: tensor([0.8499]), Std: tensor([0.2375])

# %%
# 指纹图片查看
def visualize_fvc_samples(dataset, num_people=2, samples_per_person=5):
    # 1. 建立 ID 到 索引列表的映射
    # label 是 img_name.split('_')[0] - 1
    id_to_indices = {}
    for idx, img_name in enumerate(dataset.image_files):
        label = int(img_name.split('_')[0]) - 1
        if label not in id_to_indices:
            id_to_indices[label] = []
        id_to_indices[label].append(idx)

    # 2. 随机抽取指定数量的人
    selected_ids = random.sample(list(id_to_indices.keys()), num_people)

    # 3. 开始绘图
    fig, axes = plt.subplots(num_people, samples_per_person, figsize=(15, 6), dpi=300)
    fig.suptitle('FVC2002 Fingerprint Samples Visualization', fontsize=16)

    for i, person_id in enumerate(selected_ids):
        # 随机抽取该人的 5 个指纹索引
        indices = random.sample(id_to_indices[person_id], samples_per_person)
        
        for j, idx in enumerate(indices):
            image, label = dataset[idx]
            
            # 如果 image 是 Tensor (经过了 transform)，需要转回 numpy
            if torch.is_tensor(image):
                image = image.squeeze().numpy() # 移除通道维度 [1, H, W] -> [H, W]
            
            ax = axes[i, j] if num_people > 1 else axes[j]
            ax.imshow(image, cmap='gray')
            ax.set_title(f"ID: {person_id + 1}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# 使用方法：
visualize_fvc_samples(dataset, num_people=2, samples_per_person=5)

# %% [markdown]
# ### 设定阈值后指纹图像变化

# %% [markdown]
# - 由于我们采用的是压力传感器采集，因此压力较大的区域（即纹线）会有较低的像素值（黑色），而压力较小的区域（即背景）会有较高的像素值（白色）。
# - 因此，根据压力小于阈值时，氧化铌器件不起振，我们可以将像素值高于某个阈值的区域设为1（表示背景）

# %%
# 1. 设定阈值 (范围 0 到 1，因为 ToTensor 已将像素归一化)
THRESHOLD = 0.9

# 2. 随机取出 5 个索引
indices = random.sample(range(len(dataset)), 5)

# 3. 创建画布 (5行2列：左侧原图，右侧处理后的图)
fig, axes = plt.subplots(5, 2, figsize=(10, 18))

for i, idx in enumerate(indices):
    # 获取原始图像 Tensor [1, H, W]
    img_tensor, label = dataset[idx]
    
    # 复制一份用于阈值处理
    # 逻辑：将像素值大于 THRESHOLD 的位置设为 1
    thresholded_tensor = img_tensor.clone()
    thresholded_tensor[thresholded_tensor > THRESHOLD] = 1
    
    # 将 Tensor 转换为 Numpy 以便绘图 [H, W]
    orig_np = img_tensor.squeeze().numpy()
    thresh_np = thresholded_tensor.squeeze().numpy()
    
    # 绘制原始图
    axes[i, 0].imshow(orig_np, cmap='gray', vmin=0, vmax=1)
    axes[i, 0].set_title(f"Original (Index {idx}, Label: {label})")
    axes[i, 0].axis('off')
    
    # 绘制阈值处理后的图
    axes[i, 1].imshow(thresh_np, cmap='gray', vmin=0, vmax=1)
    axes[i, 1].set_title(f"Thresholded (Value > {THRESHOLD} ---> 1)")
    axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
class ApplyTransform(Dataset):
    """
    一个简单的装饰器类，用于给 Subset 应用特定的 transform
    """
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
        
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
        
    def __len__(self):
        return len(self.subset)

# 1. 定义两个不同的 Pipeline
# 基础操作（训练和测试共有）
base_ops = [
    transforms.CenterCrop(320),  # 中心裁剪到320x320
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    # --- 核心修改：仅修改大于阈值的像素 ---
    # 逻辑：如果 x > THRESHOLD，设为 1.0；否则保留原值 x
    transforms.Lambda(lambda x: torch.where(x > THRESHOLD, torch.ones_like(x), x)),
    transforms.Normalize(mean=[0.85], std=[0.2547])     # 标准差变化
]

# 训练集特有：加入随机旋转
train_transforms = transforms.Compose([
    transforms.RandomRotation(25, fill=(255,)),  # 随机旋转 ±25 度，空白处填充白色
    *base_ops
])

# 测试集：仅基础操作
test_transforms = transforms.Compose(base_ops)

# 2. 原始数据集加载时不带 transform (或者只带 Resize)
full_dataset = FVC2002Dataset(root_dir=DATA_DIR, transform=None)

# --- 2. 建立标签到索引的映射 (字典结构) ---
# 这一步是为了找出每个手指对应的 8 张图分别在列表的哪个位置
label_to_indices = defaultdict(list)
for idx, img_name in enumerate(full_dataset.image_files):
    # 使用与你 Dataset 类中一致的解析逻辑
    label = int(img_name.split('_')[0]) - 1
    label_to_indices[label].append(idx)

train_indices = []
test_indices = []

# --- 3. 核心：对每一个类别固定分配 6/2 ---
# 确保每个类（手指）都参与了划分
for label, indices in label_to_indices.items():
    # 随机打乱当前手指的 8 张图索引
    random.shuffle(indices)
    
    # 取前 6 张作为训练，后 2 张作为测试
    train_indices.extend(indices[:6])
    test_indices.extend(indices[6:])

# --- 4. 创建 Subset 并应用不同的 Transform ---
# 先利用索引创建子集
train_subset = Subset(full_dataset, train_indices)
test_subset = Subset(full_dataset, test_indices)
# 5. 分别包装，应用不同的 transform
train_dataset = ApplyTransform(train_subset, transform=train_transforms)
test_dataset = ApplyTransform(test_subset, transform=test_transforms)

# %%
def denormalize(tensor, mean=0.85, std=0.2547):
    # 逆运算：y * std + mean
    return tensor * std + mean

# 随机选 5 个索引
sample_indices = random.sample(range(len(train_dataset)), 5)

fig, axes = plt.subplots(5, 2, figsize=(10, 20))

for i, idx in enumerate(sample_indices):
    # 1. 获取处理后的图像 (从 train_dataset，注意解包元组)
    img_processed, label = train_dataset[idx]
    
    # 2. 获取原始图像 (从 full_dataset 拿原始 Tensor 对比)
    # 注意：full_dataset 里的索引需要通过 train_indices 转换回去
    raw_idx = train_indices[idx]
    raw_img_pil, _ = full_dataset[raw_idx]
    # 简单处理以便对比
    raw_tensor = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])(raw_img_pil)

    # 绘制原始图
    axes[i, 0].imshow(raw_tensor.squeeze(), cmap='gray', vmin=0, vmax=1)
    axes[i, 0].set_title(f"Original (Index {raw_idx})")
    
    # 绘制处理后的图 (高亮部分被置为 1)
    # 注意：如果后续有 Normalize，绘图时可能需要反归一化或手动设置 vmin/vmax
    
    axes[i, 1].imshow(denormalize(img_processed.squeeze()), cmap='gray', vmin=0, vmax=1)
    axes[i, 1].set_title(f"Processed (Pixels > {THRESHOLD} -> 1.0)")
    
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
len(train_dataset), len(test_dataset)
# Out:
# (660, 220)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## 2. 构建模型

# %% [markdown]
# ### 2.1 ResNet 18

# %% [markdown]
# ### 2.1.1 调用官方预训练模型

# %%
def get_model(num_classes=110): # FVC2002 DB1 通常是 110 类
    # 1. 加载预训练模型
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    
    # 2. 保存原始的 conv1 权重
    original_conv1 = model.conv1
    
    # 3. 创建新的单通道 conv1
    model.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=False)
    
    # 4. 【核心改进】将 3 通道权重合并到 1 通道，而不是随机初始化
    # 将 RGB 权重的均值赋给单通道
    with torch.no_grad():
        model.conv1.weight.data = original_conv1.weight.data.sum(dim=1, keepdim=True)
    
    # 5. 修改全连接层
    num_ftrs = model.fc.in_features
    
    # 针对小数据集，建议在 FC 层前加个 Dropout 防止过拟合
    model.fc = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(num_ftrs, num_classes)
    )
    
    return model

# %% [markdown]
# ## 3. 模型训练

# %%
# 1. 训练一个 Epoch 的函数
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
    train_loss = running_loss / len(loader)
    train_acc = 100. * correct / total
    return train_loss, train_acc

# %%
# 2. 验证/测试函数 (基于你提供的 evaluate 修改)
def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            
    val_loss = running_loss / len(loader)
    val_acc = 100. * correct / total
    return val_loss, val_acc

# %%
# 3. 总训练控制函数
def train(model, train_loader, test_loader, criterion, optimizer, device, scheduler=None, epochs=20):
    # 用于记录历史数据以便绘图
    history = {
        'train_loss': [], 'train_acc': [],
        'test_loss': [], 'test_acc': []
    }
    
    print(f"开始训练，设备: {device}")
    for epoch in range(epochs):
        # 训练阶段
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        # 验证阶段
        test_loss, test_acc = validate(model, test_loader, criterion, device)
        
        # 每个 epoch 结束更新学习率
        if scheduler is not None:
            if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_acc)  # 以验证准确率为指标调整学习率
            else:
                scheduler.step()  # 其他类型的调度器直接调用 step()
            current_lr = optimizer.param_groups[0]['lr']

        # 记录历史
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        
        print(f"[Epoch {epoch+1}/{epochs}](LR: {current_lr:.6f}) -> "
              f"Train Acc: {train_acc:.2f}%, Test Acc: {test_acc:.2f}% | "
              f"Train Loss: {train_loss:.4f}")

    # 训练结束后进行可视化
    plot_history(history)
    return history

# 4. 可视化函数
def plot_history(history):
    epochs = range(1, len(history['train_acc']) + 1)
    
    plt.figure(figsize=(12, 5))
    
    # 绘制准确率曲线
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Acc')
    plt.plot(epochs, history['test_acc'], 'r-', label='Test Acc')
    plt.title('Training and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    
    # 绘制损失曲线
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['test_loss'], 'r-', label='Test Loss')
    plt.title('Training and Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.1 ResNet18

# %% [markdown]
# ### 3.1.1 预训练模型

# %% [markdown]
# ##### 余弦退火

# %%
resnet_pretrained_1 = get_model(num_classes=110).to(device)
optimizer = optim.Adam(resnet_pretrained_1.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-5)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in resnet_pretrained_1.parameters())
print(f"总参数量: {total_params:,}")
history1 = train(resnet_pretrained_1, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=100)
# Out:
# 总参数量: 11,226,670
# 开始训练，设备: cuda
# [Epoch 1/100](LR: 0.001000) -> Train Acc: 1.67%, Test Acc: 1.36% | Train Loss: 5.0467
# [Epoch 2/100](LR: 0.000999) -> Train Acc: 4.24%, Test Acc: 10.45% | Train Loss: 4.4213
# [Epoch 3/100](LR: 0.000998) -> Train Acc: 10.61%, Test Acc: 12.27% | Train Loss: 3.8685
# [Epoch 4/100](LR: 0.000996) -> Train Acc: 18.79%, Test Acc: 17.27% | Train Loss: 3.3150
# [Epoch 5/100](LR: 0.000994) -> Train Acc: 27.12%, Test Acc: 43.64% | Train Loss: 2.8300
# [Epoch 6/100](LR: 0.000991) -> Train Acc: 42.88%, Test Acc: 27.73% | Train Loss: 2.2920
# [Epoch 7/100](LR: 0.000988) -> Train Acc: 51.52%, Test Acc: 22.27% | Train Loss: 1.9529
# [Epoch 8/100](LR: 0.000984) -> Train Acc: 59.55%, Test Acc: 37.27% | Train Loss: 1.6154
# [Epoch 9/100](LR: 0.000980) -> Train Acc: 69.24%, Test Acc: 60.91% | Train Loss: 1.3289
# [Epoch 10/100](LR: 0.000976) -> Train Acc: 75.76%, Test Acc: 59.09% | Train Loss: 1.0694
# [Epoch 11/100](LR: 0.000971) -> Train Acc: 79.39%, Test Acc: 49.09% | Train Loss: 0.9124
# [Epoch 12/100](LR: 0.000965) -> Train Acc: 82.42%, Test Acc: 62.27% | Train Loss: 0.7878
# [Epoch 13/100](LR: 0.000959) -> Train Acc: 88.18%, Test Acc: 79.09% | Train Loss: 0.6506
# [Epoch 14/100](LR: 0.000953) -> Train Acc: 88.18%, Test Acc: 65.91% | Train Loss: 0.5810
# [Epoch 15/100](LR: 0.000946) -> Train Acc: 91.21%, Test Acc: 81.36% | Train Loss: 0.4622
# [Epoch 16/100](LR: 0.000939) -> Train Acc: 92.58%, Test Acc: 80.00% | Train Loss: 0.3989
# [Epoch 17/100](LR: 0.000931) -> Train Acc: 96.06%, Test Acc: 88.64% | Train Loss: 0.2980
# [Epoch 18/100](LR: 0.000923) -> Train Acc: 96.97%, Test Acc: 89.55% | Train Loss: 0.2291
# [Epoch 19/100](LR: 0.000914) -> Train Acc: 97.42%, Test Acc: 87.73% | Train Loss: 0.2009
# [Epoch 20/100](LR: 0.000905) -> Train Acc: 97.58%, Test Acc: 87.27% | Train Loss: 0.1762
# [Epoch 21/100](LR: 0.000896) -> Train Acc: 99.24%, Test Acc: 89.09% | Train Loss: 0.1348
# [Epoch 22/100](LR: 0.000886) -> Train Acc: 98.64%, Test Acc: 81.36% | Train Loss: 0.1216
# [Epoch 23/100](LR: 0.000876) -> Train Acc: 98.79%, Test Acc: 86.82% | Train Loss: 0.1219
# [Epoch 24/100](LR: 0.000866) -> Train Acc: 99.70%, Test Acc: 87.73% | Train Loss: 0.0864
# [Epoch 25/100](LR: 0.000855) -> Train Acc: 99.55%, Test Acc: 89.55% | Train Loss: 0.0795
# [Epoch 26/100](LR: 0.000844) -> Train Acc: 99.70%, Test Acc: 89.09% | Train Loss: 0.0708
# [Epoch 27/100](LR: 0.000832) -> Train Acc: 99.55%, Test Acc: 90.91% | Train Loss: 0.0675
# [Epoch 28/100](LR: 0.000821) -> Train Acc: 99.70%, Test Acc: 89.09% | Train Loss: 0.0664
# [Epoch 29/100](LR: 0.000808) -> Train Acc: 99.55%, Test Acc: 91.82% | Train Loss: 0.0685
# [Epoch 30/100](LR: 0.000796) -> Train Acc: 99.39%, Test Acc: 90.45% | Train Loss: 0.0514
# [Epoch 31/100](LR: 0.000783) -> Train Acc: 99.70%, Test Acc: 91.82% | Train Loss: 0.0397
# [Epoch 32/100](LR: 0.000770) -> Train Acc: 99.09%, Test Acc: 91.82% | Train Loss: 0.0619
# [Epoch 33/100](LR: 0.000757) -> Train Acc: 99.24%, Test Acc: 88.18% | Train Loss: 0.0655
# [Epoch 34/100](LR: 0.000743) -> Train Acc: 99.24%, Test Acc: 88.18% | Train Loss: 0.0853
# [Epoch 35/100](LR: 0.000730) -> Train Acc: 98.94%, Test Acc: 87.73% | Train Loss: 0.0952
# [Epoch 36/100](LR: 0.000716) -> Train Acc: 98.79%, Test Acc: 89.09% | Train Loss: 0.0797
# [Epoch 37/100](LR: 0.000702) -> Train Acc: 98.94%, Test Acc: 82.27% | Train Loss: 0.0782
# [Epoch 38/100](LR: 0.000687) -> Train Acc: 99.85%, Test Acc: 90.91% | Train Loss: 0.0464
# [Epoch 39/100](LR: 0.000673) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0296
# [Epoch 40/100](LR: 0.000658) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0178
# [Epoch 41/100](LR: 0.000643) -> Train Acc: 99.85%, Test Acc: 90.91% | Train Loss: 0.0180
# [Epoch 42/100](LR: 0.000628) -> Train Acc: 99.39%, Test Acc: 87.27% | Train Loss: 0.0460
# [Epoch 43/100](LR: 0.000613) -> Train Acc: 99.09%, Test Acc: 90.00% | Train Loss: 0.0524
# [Epoch 44/100](LR: 0.000598) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0242
# [Epoch 45/100](LR: 0.000582) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0151
# [Epoch 46/100](LR: 0.000567) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0140
# [Epoch 47/100](LR: 0.000552) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0106
# [Epoch 48/100](LR: 0.000536) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0085
# [Epoch 49/100](LR: 0.000521) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0065
# [Epoch 50/100](LR: 0.000505) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0073
# [Epoch 51/100](LR: 0.000489) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0071
# [Epoch 52/100](LR: 0.000474) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0064
# [Epoch 53/100](LR: 0.000458) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0067
# [Epoch 54/100](LR: 0.000443) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0055
# [Epoch 55/100](LR: 0.000428) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0048
# [Epoch 56/100](LR: 0.000412) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0065
# [Epoch 57/100](LR: 0.000397) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0047
# [Epoch 58/100](LR: 0.000382) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0058
# [Epoch 59/100](LR: 0.000367) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0050
# [Epoch 60/100](LR: 0.000352) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0049
# [Epoch 61/100](LR: 0.000337) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0052
# [Epoch 62/100](LR: 0.000323) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0046
# [Epoch 63/100](LR: 0.000308) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0044
# [Epoch 64/100](LR: 0.000294) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0047
# [Epoch 65/100](LR: 0.000280) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0044
# [Epoch 66/100](LR: 0.000267) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0046
# [Epoch 67/100](LR: 0.000253) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0035
# [Epoch 68/100](LR: 0.000240) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0043
# [Epoch 69/100](LR: 0.000227) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0034
# [Epoch 70/100](LR: 0.000214) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0035
# [Epoch 71/100](LR: 0.000202) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0038
# [Epoch 72/100](LR: 0.000189) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0035
# [Epoch 73/100](LR: 0.000178) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0036
# [Epoch 74/100](LR: 0.000166) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0042
# [Epoch 75/100](LR: 0.000155) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0029
# [Epoch 76/100](LR: 0.000144) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0034
# [Epoch 77/100](LR: 0.000134) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0035
# [Epoch 78/100](LR: 0.000124) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0033
# [Epoch 79/100](LR: 0.000114) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0032
# [Epoch 80/100](LR: 0.000105) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0039
# [Epoch 81/100](LR: 0.000096) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0041
# [Epoch 82/100](LR: 0.000087) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0028
# [Epoch 83/100](LR: 0.000079) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0032
# [Epoch 84/100](LR: 0.000071) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0035
# [Epoch 85/100](LR: 0.000064) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0032
# [Epoch 86/100](LR: 0.000057) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0032
# [Epoch 87/100](LR: 0.000051) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0033
# [Epoch 88/100](LR: 0.000045) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0027
# [Epoch 89/100](LR: 0.000039) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0028
# [Epoch 90/100](LR: 0.000034) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0029
# [Epoch 91/100](LR: 0.000030) -> Train Acc: 100.00%, Test Acc: 92.73% | Train Loss: 0.0028
# [Epoch 92/100](LR: 0.000026) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0030
# [Epoch 93/100](LR: 0.000022) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0034
# [Epoch 94/100](LR: 0.000019) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0031
# [Epoch 95/100](LR: 0.000016) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0038
# [Epoch 96/100](LR: 0.000014) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0028
# [Epoch 97/100](LR: 0.000012) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0029
# [Epoch 98/100](LR: 0.000011) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0039
# [Epoch 99/100](LR: 0.000010) -> Train Acc: 100.00%, Test Acc: 93.18% | Train Loss: 0.0029
# [Epoch 100/100](LR: 0.000010) -> Train Acc: 100.00%, Test Acc: 93.64% | Train Loss: 0.0032

# %% [markdown]
# ##### ReduceLROnPlateau

# %%
resnet_pretrained_2 = get_model(num_classes=110).to(device)
optimizer = optim.Adam(resnet_pretrained_2.parameters(), lr=0.001)
# 进行学习率衰退, 使用CosineAnnealingLR
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)
criterion = nn.CrossEntropyLoss()
total_params = sum(p.numel() for p in resnet_pretrained_2.parameters())
print(f"总参数量: {total_params:,}")
history2 = train(resnet_pretrained_2, train_loader, test_loader, criterion, optimizer, device, scheduler, epochs=100)
# Out:
# 总参数量: 11,226,670
# 开始训练，设备: cuda
# [Epoch 1/100](LR: 0.001000) -> Train Acc: 1.52%, Test Acc: 0.45% | Train Loss: 5.0863
# [Epoch 2/100](LR: 0.001000) -> Train Acc: 3.33%, Test Acc: 0.91% | Train Loss: 4.6348
# [Epoch 3/100](LR: 0.001000) -> Train Acc: 4.24%, Test Acc: 4.09% | Train Loss: 4.3740
# [Epoch 4/100](LR: 0.001000) -> Train Acc: 7.73%, Test Acc: 10.91% | Train Loss: 3.9195
# [Epoch 5/100](LR: 0.001000) -> Train Acc: 12.73%, Test Acc: 12.73% | Train Loss: 3.5850
# [Epoch 6/100](LR: 0.001000) -> Train Acc: 21.06%, Test Acc: 20.45% | Train Loss: 3.1600
# [Epoch 7/100](LR: 0.001000) -> Train Acc: 26.52%, Test Acc: 33.64% | Train Loss: 2.8298
# [Epoch 8/100](LR: 0.001000) -> Train Acc: 30.76%, Test Acc: 42.27% | Train Loss: 2.4450
# [Epoch 9/100](LR: 0.001000) -> Train Acc: 43.79%, Test Acc: 45.91% | Train Loss: 2.0944
# [Epoch 10/100](LR: 0.001000) -> Train Acc: 47.88%, Test Acc: 52.73% | Train Loss: 1.9109
# [Epoch 11/100](LR: 0.001000) -> Train Acc: 58.33%, Test Acc: 24.09% | Train Loss: 1.6823
# [Epoch 12/100](LR: 0.001000) -> Train Acc: 62.12%, Test Acc: 49.09% | Train Loss: 1.4242
# [Epoch 13/100](LR: 0.001000) -> Train Acc: 72.42%, Test Acc: 61.82% | Train Loss: 1.1703
# [Epoch 14/100](LR: 0.001000) -> Train Acc: 74.39%, Test Acc: 65.45% | Train Loss: 1.0270
# [Epoch 15/100](LR: 0.001000) -> Train Acc: 80.30%, Test Acc: 46.36% | Train Loss: 0.8836
# [Epoch 16/100](LR: 0.001000) -> Train Acc: 87.42%, Test Acc: 67.27% | Train Loss: 0.6402
# [Epoch 17/100](LR: 0.001000) -> Train Acc: 86.67%, Test Acc: 78.64% | Train Loss: 0.6525
# [Epoch 18/100](LR: 0.001000) -> Train Acc: 88.64%, Test Acc: 64.55% | Train Loss: 0.5584
# [Epoch 19/100](LR: 0.001000) -> Train Acc: 90.00%, Test Acc: 65.00% | Train Loss: 0.4964
# [Epoch 20/100](LR: 0.001000) -> Train Acc: 90.45%, Test Acc: 75.45% | Train Loss: 0.5028
# [Epoch 21/100](LR: 0.000500) -> Train Acc: 90.30%, Test Acc: 67.73% | Train Loss: 0.4692
# [Epoch 22/100](LR: 0.000500) -> Train Acc: 94.85%, Test Acc: 90.00% | Train Loss: 0.2988
# [Epoch 23/100](LR: 0.000500) -> Train Acc: 97.42%, Test Acc: 87.73% | Train Loss: 0.1893
# [Epoch 24/100](LR: 0.000500) -> Train Acc: 97.88%, Test Acc: 90.00% | Train Loss: 0.1701
# [Epoch 25/100](LR: 0.000500) -> Train Acc: 98.94%, Test Acc: 87.73% | Train Loss: 0.1339
# [Epoch 26/100](LR: 0.000500) -> Train Acc: 99.55%, Test Acc: 90.91% | Train Loss: 0.1201
# [Epoch 27/100](LR: 0.000500) -> Train Acc: 99.70%, Test Acc: 90.45% | Train Loss: 0.0924
# [Epoch 28/100](LR: 0.000500) -> Train Acc: 99.55%, Test Acc: 89.55% | Train Loss: 0.1005
# [Epoch 29/100](LR: 0.000500) -> Train Acc: 99.85%, Test Acc: 90.45% | Train Loss: 0.0862
# [Epoch 30/100](LR: 0.000250) -> Train Acc: 99.55%, Test Acc: 88.18% | Train Loss: 0.0721
# [Epoch 31/100](LR: 0.000250) -> Train Acc: 99.85%, Test Acc: 90.45% | Train Loss: 0.0595
# [Epoch 32/100](LR: 0.000250) -> Train Acc: 100.00%, Test Acc: 90.00% | Train Loss: 0.0607
# [Epoch 33/100](LR: 0.000250) -> Train Acc: 100.00%, Test Acc: 90.45% | Train Loss: 0.0465
# [Epoch 34/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 90.91% | Train Loss: 0.0423
# [Epoch 35/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 90.91% | Train Loss: 0.0376
# [Epoch 36/100](LR: 0.000125) -> Train Acc: 99.85%, Test Acc: 90.91% | Train Loss: 0.0442
# [Epoch 37/100](LR: 0.000125) -> Train Acc: 99.70%, Test Acc: 91.36% | Train Loss: 0.0434
# [Epoch 38/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0330
# [Epoch 39/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0402
# [Epoch 40/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0379
# [Epoch 41/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0369
# [Epoch 42/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0368
# [Epoch 43/100](LR: 0.000125) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0396
# [Epoch 44/100](LR: 0.000063) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0326
# [Epoch 45/100](LR: 0.000063) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0313
# [Epoch 46/100](LR: 0.000063) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0315
# [Epoch 47/100](LR: 0.000063) -> Train Acc: 100.00%, Test Acc: 90.45% | Train Loss: 0.0308
# [Epoch 48/100](LR: 0.000031) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0352
# [Epoch 49/100](LR: 0.000031) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0358
# [Epoch 50/100](LR: 0.000031) -> Train Acc: 99.85%, Test Acc: 90.91% | Train Loss: 0.0313
# [Epoch 51/100](LR: 0.000031) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0311
# [Epoch 52/100](LR: 0.000016) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0292
# [Epoch 53/100](LR: 0.000016) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0252
# [Epoch 54/100](LR: 0.000016) -> Train Acc: 99.70%, Test Acc: 91.82% | Train Loss: 0.0338
# [Epoch 55/100](LR: 0.000016) -> Train Acc: 99.85%, Test Acc: 91.36% | Train Loss: 0.0370
# [Epoch 56/100](LR: 0.000008) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0299
# [Epoch 57/100](LR: 0.000008) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0301
# [Epoch 58/100](LR: 0.000008) -> Train Acc: 99.85%, Test Acc: 91.36% | Train Loss: 0.0319
# [Epoch 59/100](LR: 0.000008) -> Train Acc: 100.00%, Test Acc: 90.91% | Train Loss: 0.0269
# [Epoch 60/100](LR: 0.000004) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0281
# [Epoch 61/100](LR: 0.000004) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0255
# [Epoch 62/100](LR: 0.000004) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0238
# [Epoch 63/100](LR: 0.000004) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0293
# [Epoch 64/100](LR: 0.000002) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0278
# [Epoch 65/100](LR: 0.000002) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0311
# [Epoch 66/100](LR: 0.000002) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0289
# [Epoch 67/100](LR: 0.000002) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0295
# [Epoch 68/100](LR: 0.000001) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0320
# [Epoch 69/100](LR: 0.000001) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0260
# [Epoch 70/100](LR: 0.000001) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0289
# [Epoch 71/100](LR: 0.000001) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0299
# [Epoch 72/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0231
# [Epoch 73/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0274
# [Epoch 74/100](LR: 0.000000) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0297
# [Epoch 75/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 92.27% | Train Loss: 0.0305
# [Epoch 76/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0296
# [Epoch 77/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0307
# [Epoch 78/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0237
# [Epoch 79/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0282
# [Epoch 80/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0260
# [Epoch 81/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0256
# [Epoch 82/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0307
# [Epoch 83/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0333
# [Epoch 84/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0282
# [Epoch 85/100](LR: 0.000000) -> Train Acc: 99.55%, Test Acc: 91.82% | Train Loss: 0.0334
# [Epoch 86/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0287
# [Epoch 87/100](LR: 0.000000) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0293
# [Epoch 88/100](LR: 0.000000) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0335
# [Epoch 89/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0269
# [Epoch 90/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0302
# [Epoch 91/100](LR: 0.000000) -> Train Acc: 99.85%, Test Acc: 91.36% | Train Loss: 0.0269
# [Epoch 92/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0297
# [Epoch 93/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0292
# [Epoch 94/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0296
# [Epoch 95/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.36% | Train Loss: 0.0285
# [Epoch 96/100](LR: 0.000000) -> Train Acc: 99.70%, Test Acc: 91.82% | Train Loss: 0.0286
# [Epoch 97/100](LR: 0.000000) -> Train Acc: 99.85%, Test Acc: 91.82% | Train Loss: 0.0318
# [Epoch 98/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0281
# [Epoch 99/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0265
# [Epoch 100/100](LR: 0.000000) -> Train Acc: 100.00%, Test Acc: 91.82% | Train Loss: 0.0315
